# %% [markdown]
# # 0. Preliminaries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import platform
import re

# %%
'''
if platform.system() == 'Darwin':
    user = 'joewandy'
elif platform.system() == 'Windows':
    user = 'joewa'
    
user_vimms = '/Users/%s/Work/git/vimms' % user
'''
#user_vimms = os.path.join("C:\\", "Users", "mcbrider5002", "Desktop", "Workspace", "phd", "peak_picking", "vimms")
user_vimms = "vimms"
sys.path.append(user_vimms)

# %%
from vimms.Common import (
    POSITIVE, ROI_TYPE_SMART, ROI_EXCLUSION_WEIGHTED_DEW,
    set_log_level_warning,
)

from vimms.Roi import RoiBuilderParams, SmartRoiParams
from vimms.Experiment import ExperimentCase, Experiment

# %%
ionisation_mode = POSITIVE
pbar = False
set_log_level_warning()
# Out:
# 1

# %% [markdown]
# ### Get seed data

# %%
def match_files(data_dir, regex):
    pattern = re.compile(regex)
    files = (
        (int(pattern.match(fname).group(1)), fname)
        for fname in os.listdir(data_dir)
        if not pattern.match(fname) is None
    )

    return [
        os.path.join(data_dir, fname) 
        for _, fname in sorted(files, key=lambda p: p[0])
    ]

# %%
#multi_dir = "/Users/%s/University of Glasgow/Vinny Davies - CLDS Metabolomics Project/Experimental_Results/20220706_DDAvsDIA" % user
multi_dir = "20220706_DDAvsDIA"
multibeer_dir = os.path.join(multi_dir, "results_1")

# %%
multibeer_fullscans = match_files(multibeer_dir, r"fullscan_beer([0-9]+)_0.mzML")

# %% [markdown]
# ### Specify parameters

# %%
num_workers = 48 #can't always use number of physical cores because of memory constraints

# %%
search_params = {
    "topN_params" : {
        "N" : [1, 3, 5, 10, 20],
        #"N" : [1, 5],
        "rt_tol" : [15, 30, 60, 120, 240]
       # "rt_tol" : [60, 120]
    },
    
    "smartroi_params" : {
        "N" : [1, 3, 5, 10, 20],
        #"N" : [1, 5],
        "rt_tol" : [15],
        "smartroi_params" : [
            SmartRoiParams(
                reset_length_seconds=1E6,
                intensity_increase_factor=alpha,
                drop_perc=beta
            )
            for alpha in [2, 3, 5, 10] for beta in [0, 1E-3, 1E-2, 1E-1]
            #for alpha in [2, 3] for beta in [0, 1E-3]
        ]
    },
    
    "weighteddew_params" : {
        "exclusion_method": [ROI_EXCLUSION_WEIGHTED_DEW],
        "N" : [1, 3, 5, 10, 20],
        #"N" : [1, 5],
        "rt_tol" : [15, 30, 60, 120, 240],
        #"rt_tol" : [15, 30],
        "exclusion_t_0" : [1, 10, 15, 30, 60]
        #"exclusion_t_0" : [1, 10]
    }
}

# %%
shared_params = {
    "topN_params": {
        "ionisation_mode" : ionisation_mode,
        "isolation_width" : 1,
        "min_ms1_intensity" : 5000,
        "mz_tol" : 10,
    },
    
    "roi_params" : {
        "min_roi_length_for_fragmentation" : 0,
        "roi_params" : RoiBuilderParams(
                            min_roi_intensity=0,
                            min_roi_length=3,
                       )
    }
}

min_rt = 0
max_rt = 1440
scan_duration_dict = {
    1: 0.59,
    2: 0.19
}

# %%
topN_shared = shared_params["topN_params"]
roi_shared = {**topN_shared, **shared_params["roi_params"]}

# %% [markdown]
# # Grid Search

# %%
bio_repeat = 3
tech_repeat = 2
out_dir = "real_grid_search"

search_exp = Experiment.run_grid_search(
    "intensity_non_overlap",
    multibeer_fullscans[:bio_repeat] * tech_repeat,
    roi_shared,
    search_params,
    out_dir,
    min_rt=min_rt,
    max_rt=max_rt,
    ionisation_mode=ionisation_mode,
    scan_duration_dict=scan_duration_dict,
    num_workers=num_workers
)
# Out:
# GRID SEARCH OF 230 CASES
# Creating Chemicals...
# Generating chemicals for multibeers_urine_data/beers/fullscan/mzML/Beer_multibeers_2_fullscan1.mzMLGenerating chemicals for multibeers_urine_data/beers/fullscan/mzML/Beer_multibeers_1_fullscan1.mzMLGenerating chemicals for multibeers_urine_data/beers/fullscan/mzML/Beer_multibeers_3_fullscan1.mzML
#
#
#
# Running Experiment...
# Outcome being written to: "topN_params_2_0.mzML"
# Outcome being written to: "topN_params_4_0.mzML"
# Outcome being written to: "topN_params_10_0.mzML"
# Outcome being written to: "topN_params_0_0.mzML"
# Outcome being written to: "topN_params_12_0.mzML"
# Outcome being written to: "topN_params_16_0.mzML"
# Outcome being written to: "topN_params_8_0.mzML"
# Outcome being written to: "topN_params_18_0.mzML"
# Outcome being written to: "topN_params_14_0.mzML"
# Outcome being written to: "topN_params_6_0.mzML"
# Outcome being written to: "topN_params_24_0.mzML"
# Outcome being written to: "smartroi_params_9_0.mzML"
# Outcome being written to: "topN_params_22_0.mzML"
# Outcome being written to: "smartroi_params_1_0.mzML"
# Outcome being written to: "smartroi_params_23_0.mzML"
# Outcome being written to: "smartroi_params_5_0.mzML"
# Outcome being written to: "smartroi_params_13_0.mzML"
# Outcome being written to: "smartroi_params_17_0.mzML"
# Outcome being written to: "smartroi_params_11_0.mzML"
# Outcome being written to: "smartroi_params_7_0.mzML"
# Outcome being written to: "smartroi_params_21_0.mzML"
# Outcome being written to: "smartroi_params_43_0.mzML"
# Outcome being written to: "smartroi_params_45_0.mzML"
# Outcome being written to: "smartroi_params_3_0.mzML"
# Outcome being written to: "smartroi_params_35_0.mzML"
# Outcome being written to: "smartroi_params_25_0.mzML"
# Outcome being written to: "smartroi_params_31_0.mzML"
# Outcome being written to: "smartroi_params_27_0.mzML"
# Outcome being written to: "smartroi_params_47_0.mzML"
# Outcome being written to: "smartroi_params_39_0.mzML"
# Outcome being written to: "smartroi_params_29_0.mzML"
# Outcome being written to: "smartroi_params_33_0.mzML"
# Outcome being written to: "smartroi_params_65_0.mzML"
# Outcome being written to: "smartroi_params_51_0.mzML"
# Outcome being written to: "smartroi_params_55_0.mzML"
# Outcome being written to: "smartroi_params_63_0.mzML"
# Outcome being written to: "smartroi_params_19_0.mzML"
# Outcome being written to: "smartroi_params_53_0.mzML"
# Outcome being written to: "smartroi_params_57_0.mzML"
# Outcome being written to: "topN_params_20_0.mzML"
# Outcome being written to: "smartroi_params_69_0.mzML"
# Outcome being written to: "smartroi_params_37_0.mzML"
# Outcome being written to: "smartroi_params_15_0.mzML"
# Outcome being written to: "smartroi_params_49_0.mzML"
# Outcome being written to: "smartroi_params_41_0.mzML"
# Outcome being written to: "smartroi_params_59_0.mzML"
# Outcome being written to: "smartroi_params_67_0.mzML"
# Outcome being written to: "smartroi_params_61_0.mzML"
# Outcome being written to: "topN_params_10_1.mzML"
# Outcome being written to: "topN_params_16_1.mzML"
# Outcome being written to: "topN_params_20_1.mzML"
# Outcome being written to: "topN_params_22_1.mzML"
# Outcome being written to: "topN_params_12_1.mzML"
# Outcome being written to: "topN_params_24_1.mzML"
# Outcome being written to: "topN_params_18_1.mzML"
# Outcome being written to: "topN_params_6_1.mzML"
# Outcome being written to: "smartroi_params_65_1.mzML"
# Outcome being written to: "topN_params_0_1.mzML"
# Outcome being written to: "topN_params_8_1.mzML"
# Outcome being written to: "topN_params_14_1.mzML"
# Outcome being written to: "smartroi_params_55_1.mzML"
# Outcome being written to: "topN_params_2_1.mzML"
# Outcome being written to: "smartroi_params_69_1.mzML"
# Outcome being written to: "smartroi_params_35_1.mzML"
# Outcome being written to: "smartroi_params_43_1.mzML"
# Outcome being written to: "topN_params_4_1.mzML"
# Outcome being written to: "smartroi_params_33_1.mzML"
# Outcome being written to: "smartroi_params_45_1.mzML"
# Outcome being written to: "smartroi_params_51_1.mzML"
# Outcome being written to: "smartroi_params_53_1.mzML"
# Outcome being written to: "smartroi_params_39_1.mzML"
# Outcome being written to: "smartroi_params_17_1.mzML"
# Outcome being written to: "smartroi_params_57_1.mzML"
# Outcome being written to: "smartroi_params_21_1.mzML"
# Outcome being written to: "smartroi_params_23_1.mzML"
# Outcome being written to: "smartroi_params_63_1.mzML"
# Outcome being written to: "smartroi_params_47_1.mzML"
# Outcome being written to: "smartroi_params_27_1.mzML"
# Outcome being written to: "smartroi_params_67_1.mzML"
# Outcome being written to: "smartroi_params_25_1.mzML"
# Outcome being written to: "smartroi_params_9_1.mzML"
# Outcome being written to: "smartroi_params_1_1.mzML"
# Outcome being written to: "smartroi_params_7_1.mzML"
# Outcome being written to: "smartroi_params_29_1.mzML"
# Outcome being written to: "smartroi_params_5_1.mzML"
# Outcome being written to: "smartroi_params_41_1.mzML"
# Outcome being written to: "smartroi_params_31_1.mzML"
# Outcome being written to: "smartroi_params_11_1.mzML"
# Outcome being written to: "smartroi_params_49_1.mzML"
# Outcome being written to: "smartroi_params_37_1.mzML"
# Outcome being written to: "smartroi_params_13_1.mzML"
# Outcome being written to: "smartroi_params_59_1.mzML"
# Outcome being written to: "smartroi_params_61_1.mzML"
# Outcome being written to: "smartroi_params_19_1.mzML"
# Outcome being written to: "smartroi_params_3_1.mzML"
# Outcome being written to: "smartroi_params_15_1.mzML"
# Outcome being written to: "topN_params_20_2.mzML"
# Outcome being written to: "topN_params_16_2.mzML"
# Outcome being written to: "topN_params_10_2.mzML"
# Outcome being written to: "topN_params_22_2.mzML"
# Outcome being written to: "topN_params_24_2.mzML"
# Outcome being written to: "topN_params_18_2.mzML"
# Outcome being written to: "topN_params_12_2.mzML"
# Outcome being written to: "smartroi_params_65_2.mzML"
# Outcome being written to: "topN_params_6_2.mzML"
# Outcome being written to: "smartroi_params_69_2.mzML"
# Outcome being written to: "smartroi_params_55_2.mzML"
# Outcome being written to: "topN_params_0_2.mzML"
# Outcome being written to: "topN_params_14_2.mzML"
# Outcome being written to: "topN_params_8_2.mzML"
# Outcome being written to: "smartroi_params_33_2.mzML"
# Outcome being written to: "smartroi_params_43_2.mzML"
# Outcome being written to: "smartroi_params_53_2.mzML"
# Outcome being written to: "smartroi_params_35_2.mzML"
# Outcome being written to: "smartroi_params_51_2.mzML"
# Outcome being written to: "topN_params_2_2.mzML"
# Outcome being written to: "smartroi_params_39_2.mzML"
# Outcome being written to: "smartroi_params_45_2.mzML"
# Outcome being written to: "smartroi_params_17_2.mzML"
# Outcome being written to: "topN_params_4_2.mzML"
# Outcome being written to: "smartroi_params_21_2.mzML"
# Outcome being written to: "smartroi_params_47_2.mzML"
# Outcome being written to: "smartroi_params_63_2.mzML"
# Outcome being written to: "smartroi_params_23_2.mzML"
# Outcome being written to: "smartroi_params_27_2.mzML"
# Outcome being written to: "smartroi_params_57_2.mzML"
# Outcome being written to: "smartroi_params_67_2.mzML"
# Outcome being written to: "smartroi_params_25_2.mzML"
# Outcome being written to: "smartroi_params_31_2.mzML"
# Outcome being written to: "smartroi_params_41_2.mzML"
# Outcome being written to: "smartroi_params_7_2.mzML"
# Outcome being written to: "smartroi_params_49_2.mzML"
# Outcome being written to: "smartroi_params_9_2.mzML"
# Outcome being written to: "smartroi_params_1_2.mzML"
# Outcome being written to: "smartroi_params_29_2.mzML"
# Outcome being written to: "smartroi_params_61_2.mzML"
# Outcome being written to: "smartroi_params_59_2.mzML"
# Outcome being written to: "smartroi_params_5_2.mzML"
# Outcome being written to: "smartroi_params_37_2.mzML"
# Outcome being written to: "smartroi_params_11_2.mzML"
# Outcome being written to: "smartroi_params_13_2.mzML"
# Outcome being written to: "smartroi_params_19_2.mzML"
# Outcome being written to: "smartroi_params_3_2.mzML"
# Outcome being written to: "topN_params_20_3.mzML"
# Outcome being written to: "smartroi_params_15_2.mzML"
# Outcome being written to: "topN_params_10_3.mzML"
# Outcome being written to: "topN_params_16_3.mzML"
# Outcome being written to: "topN_params_22_3.mzML"
# Outcome being written to: "topN_params_24_3.mzML"
# Outcome being written to: "topN_params_12_3.mzML"
# Outcome being written to: "topN_params_6_3.mzML"
# Outcome being written to: "smartroi_params_65_3.mzML"
# Outcome being written to: "topN_params_18_3.mzML"
# Outcome being written to: "topN_params_0_3.mzML"
# Outcome being written to: "smartroi_params_69_3.mzML"
# Outcome being written to: "smartroi_params_55_3.mzML"
# Outcome being written to: "topN_params_14_3.mzML"
# Outcome being written to: "smartroi_params_53_3.mzML"
# Outcome being written to: "topN_params_8_3.mzML"
# Outcome being written to: "smartroi_params_33_3.mzML"
# Outcome being written to: "smartroi_params_51_3.mzML"
# Outcome being written to: "smartroi_params_43_3.mzML"
# Outcome being written to: "topN_params_2_3.mzML"
# Outcome being written to: "smartroi_params_39_3.mzML"
# Outcome being written to: "smartroi_params_63_3.mzML"
# Outcome being written to: "smartroi_params_17_3.mzML"
# Outcome being written to: "smartroi_params_45_3.mzML"
# Outcome being written to: "topN_params_4_3.mzML"
# Outcome being written to: "smartroi_params_23_3.mzML"
# Outcome being written to: "smartroi_params_21_3.mzML"
# Outcome being written to: "smartroi_params_35_3.mzML"
# Outcome being written to: "smartroi_params_27_3.mzML"
# Outcome being written to: "smartroi_params_57_3.mzML"
# Outcome being written to: "topN_params_20_4.mzML"
# Outcome being written to: "smartroi_params_67_3.mzML"
# Outcome being written to: "smartroi_params_31_3.mzML"
# Outcome being written to: "smartroi_params_25_3.mzML"
# Outcome being written to: "smartroi_params_41_3.mzML"
# Outcome being written to: "smartroi_params_47_3.mzML"
# Outcome being written to: "smartroi_params_61_3.mzML"
# Outcome being written to: "smartroi_params_7_3.mzML"
# Outcome being written to: "smartroi_params_49_3.mzML"
# Outcome being written to: "smartroi_params_37_3.mzML"
# Outcome being written to: "smartroi_params_1_3.mzML"
# Outcome being written to: "smartroi_params_29_3.mzML"
# Outcome being written to: "smartroi_params_9_3.mzML"
# Outcome being written to: "smartroi_params_5_3.mzML"
# Outcome being written to: "topN_params_10_4.mzML"
# Outcome being written to: "topN_params_16_4.mzML"
# Outcome being written to: "smartroi_params_11_3.mzML"
# Outcome being written to: "smartroi_params_59_3.mzML"
# Outcome being written to: "smartroi_params_19_3.mzML"
# Outcome being written to: "smartroi_params_13_3.mzML"
# Outcome being written to: "topN_params_22_4.mzML"
# Outcome being written to: "smartroi_params_3_3.mzML"
# Outcome being written to: "smartroi_params_15_3.mzML"
# Outcome being written to: "topN_params_24_4.mzML"
# Outcome being written to: "topN_params_6_4.mzML"
# Outcome being written to: "topN_params_12_4.mzML"
# Outcome being written to: "smartroi_params_65_4.mzML"
# Outcome being written to: "topN_params_18_4.mzML"
# Outcome being written to: "topN_params_0_4.mzML"
# Outcome being written to: "smartroi_params_69_4.mzML"
# Outcome being written to: "smartroi_params_55_4.mzML"
# Outcome being written to: "topN_params_14_4.mzML"
# Outcome being written to: "topN_params_20_5.mzML"
# Outcome being written to: "smartroi_params_51_4.mzML"
# Outcome being written to: "smartroi_params_33_4.mzML"
# Outcome being written to: "topN_params_8_4.mzML"
# Outcome being written to: "topN_params_2_4.mzML"
# Outcome being written to: "smartroi_params_53_4.mzML"
# Outcome being written to: "smartroi_params_43_4.mzML"
# Outcome being written to: "smartroi_params_39_4.mzML"
# Outcome being written to: "smartroi_params_17_4.mzML"
# Outcome being written to: "smartroi_params_63_4.mzML"
# Outcome being written to: "topN_params_4_4.mzML"
# Outcome being written to: "smartroi_params_45_4.mzML"
# Outcome being written to: "smartroi_params_21_4.mzML"
# Outcome being written to: "smartroi_params_27_4.mzML"
# Outcome being written to: "topN_params_16_5.mzML"
# Outcome being written to: "topN_params_10_5.mzML"
# Outcome being written to: "smartroi_params_23_4.mzML"
# Outcome being written to: "smartroi_params_57_4.mzML"
# Outcome being written to: "smartroi_params_67_4.mzML"
# Outcome being written to: "smartroi_params_61_4.mzML"
# Outcome being written to: "smartroi_params_31_4.mzML"
# Outcome being written to: "smartroi_params_25_4.mzML"
# Outcome being written to: "smartroi_params_35_4.mzML"
# Outcome being written to: "smartroi_params_41_4.mzML"
# Outcome being written to: "smartroi_params_7_4.mzML"
# Outcome being written to: "smartroi_params_37_4.mzML"
# Outcome being written to: "smartroi_params_1_4.mzML"
# Outcome being written to: "smartroi_params_49_4.mzML"
# Outcome being written to: "smartroi_params_47_4.mzML"
# Outcome being written to: "smartroi_params_29_4.mzML"
# Outcome being written to: "smartroi_params_9_4.mzML"
# Outcome being written to: "smartroi_params_11_4.mzML"
# Outcome being written to: "smartroi_params_5_4.mzML"
# Outcome being written to: "topN_params_22_5.mzML"
# Outcome being written to: "smartroi_params_59_4.mzML"
# Outcome being written to: "smartroi_params_19_4.mzML"
# Outcome being written to: "smartroi_params_13_4.mzML"
# Outcome being written to: "smartroi_params_3_4.mzML"
# Outcome being written to: "topN_params_24_5.mzML"
# Outcome being written to: "topN_params_12_5.mzML"
# Outcome being written to: "topN_params_6_5.mzML"
# Outcome being written to: "smartroi_params_65_5.mzML"
# Outcome being written to: "smartroi_params_15_4.mzML"
# Outcome being written to: "topN_params_18_5.mzML"
# Outcome being written to: "topN_params_0_5.mzML"
# Outcome being written to: "topN_params_21_0.mzML"
# Outcome being written to: "smartroi_params_69_5.mzML"
# Outcome being written to: "smartroi_params_55_5.mzML"
# Outcome being written to: "smartroi_params_51_5.mzML"
# Outcome being written to: "topN_params_11_0.mzML"
# Outcome being written to: "topN_params_17_0.mzML"
# Outcome being written to: "topN_params_2_5.mzML"
# Outcome being written to: "smartroi_params_33_5.mzML"
# Outcome being written to: "smartroi_params_53_5.mzML"
# Outcome being written to: "topN_params_14_5.mzML"
# Outcome being written to: "smartroi_params_43_5.mzML"
# Outcome being written to: "topN_params_8_5.mzML"
# Outcome being written to: "smartroi_params_17_5.mzML"
# Outcome being written to: "smartroi_params_63_5.mzML"
# Outcome being written to: "topN_params_4_5.mzML"
# Outcome being written to: "smartroi_params_45_5.mzML"
# Outcome being written to: "smartroi_params_27_5.mzML"
# Outcome being written to: "smartroi_params_21_5.mzML"
# Outcome being written to: "smartroi_params_39_5.mzML"
# Outcome being written to: "smartroi_params_23_5.mzML"
# Outcome being written to: "smartroi_params_57_5.mzML"
# Outcome being written to: "smartroi_params_67_5.mzML"
# Outcome being written to: "smartroi_params_31_5.mzML"
# Outcome being written to: "smartroi_params_25_5.mzML"
# Outcome being written to: "smartroi_params_61_5.mzML"
# Outcome being written to: "topN_params_23_0.mzML"
# Outcome being written to: "smartroi_params_41_5.mzML"
# Outcome being written to: "smartroi_params_7_5.mzML"
# Outcome being written to: "smartroi_params_37_5.mzML"
# Outcome being written to: "smartroi_params_1_5.mzML"
# Outcome being written to: "smartroi_params_35_5.mzML"
# Outcome being written to: "smartroi_params_29_5.mzML"
# Outcome being written to: "smartroi_params_9_5.mzML"
# Outcome being written to: "smartroi_params_5_5.mzML"
# Outcome being written to: "smartroi_params_49_5.mzML"
# Outcome being written to: "smartroi_params_11_5.mzML"
# Outcome being written to: "smartroi_params_47_5.mzML"
# Outcome being written to: "smartroi_params_59_5.mzML"
# Outcome being written to: "topN_params_21_1.mzML"
# Outcome being written to: "smartroi_params_13_5.mzML"
# Outcome being written to: "smartroi_params_19_5.mzML"
# Outcome being written to: "topN_params_7_0.mzML"
# Outcome being written to: "topN_params_11_1.mzML"
# Outcome being written to: "topN_params_17_1.mzML"
# Outcome being written to: "topN_params_13_0.mzML"
# Outcome being written to: "topN_params_1_0.mzML"
# Outcome being written to: "smartroi_params_0_0.mzML"
# Outcome being written to: "smartroi_params_3_5.mzML"
# Outcome being written to: "smartroi_params_66_0.mzML"
# Outcome being written to: "topN_params_19_0.mzML"
# Outcome being written to: "smartroi_params_70_0.mzML"
# Outcome being written to: "smartroi_params_56_0.mzML"
# Outcome being written to: "smartroi_params_15_5.mzML"
# Outcome being written to: "smartroi_params_52_0.mzML"
# Outcome being written to: "topN_params_23_1.mzML"
# Outcome being written to: "topN_params_3_0.mzML"
# Outcome being written to: "smartroi_params_34_0.mzML"
# Outcome being written to: "topN_params_9_0.mzML"
# Outcome being written to: "smartroi_params_44_0.mzML"
# Outcome being written to: "smartroi_params_54_0.mzML"
# Outcome being written to: "topN_params_15_0.mzML"
# Outcome being written to: "smartroi_params_18_0.mzML"
# Outcome being written to: "topN_params_5_0.mzML"
# Outcome being written to: "smartroi_params_64_0.mzML"
# Outcome being written to: "smartroi_params_28_0.mzML"
# Outcome being written to: "smartroi_params_22_0.mzML"
# Outcome being written to: "smartroi_params_46_0.mzML"
# Outcome being written to: "smartroi_params_40_0.mzML"
# Outcome being written to: "smartroi_params_24_0.mzML"
# Outcome being written to: "smartroi_params_32_0.mzML"
# Outcome being written to: "smartroi_params_68_0.mzML"
# Outcome being written to: "smartroi_params_58_0.mzML"
# Outcome being written to: "topN_params_21_2.mzML"
# Outcome being written to: "smartroi_params_8_0.mzML"
# Outcome being written to: "smartroi_params_26_0.mzML"
# Outcome being written to: "smartroi_params_2_0.mzML"
# Outcome being written to: "smartroi_params_30_0.mzML"
# Outcome being written to: "smartroi_params_62_0.mzML"
# Outcome being written to: "smartroi_params_42_0.mzML"
# Outcome being written to: "smartroi_params_6_0.mzML"
# Outcome being written to: "smartroi_params_36_0.mzML"
# Outcome being written to: "smartroi_params_12_0.mzML"
# Outcome being written to: "smartroi_params_10_0.mzML"
# Outcome being written to: "topN_params_11_2.mzML"
# Outcome being written to: "topN_params_17_2.mzML"
# Outcome being written to: "smartroi_params_38_0.mzML"
# Outcome being written to: "topN_params_13_1.mzML"
# Outcome being written to: "smartroi_params_50_0.mzML"
# Outcome being written to: "topN_params_1_1.mzML"
# Outcome being written to: "topN_params_7_1.mzML"
# Outcome being written to: "smartroi_params_60_0.mzML"
# Outcome being written to: "smartroi_params_66_1.mzML"
# Outcome being written to: "smartroi_params_48_0.mzML"
# Outcome being written to: "smartroi_params_70_1.mzML"
# Outcome being written to: "topN_params_19_1.mzML"
# Outcome being written to: "smartroi_params_0_1.mzML"
# Outcome being written to: "smartroi_params_14_0.mzML"
# Outcome being written to: "smartroi_params_20_0.mzML"
# Outcome being written to: "smartroi_params_56_1.mzML"
# Outcome being written to: "topN_params_23_2.mzML"
# Outcome being written to: "topN_params_15_1.mzML"
# Outcome being written to: "topN_params_3_1.mzML"
# Outcome being written to: "smartroi_params_52_1.mzML"
# Outcome being written to: "smartroi_params_4_0.mzML"
# Outcome being written to: "smartroi_params_34_1.mzML"
# Outcome being written to: "topN_params_5_1.mzML"
# Outcome being written to: "smartroi_params_44_1.mzML"
# Outcome being written to: "smartroi_params_54_1.mzML"
# Outcome being written to: "smartroi_params_64_1.mzML"
# Outcome being written to: "topN_params_9_1.mzML"
# Outcome being written to: "smartroi_params_18_1.mzML"
# Outcome being written to: "smartroi_params_16_0.mzML"
# Outcome being written to: "smartroi_params_22_1.mzML"
# Outcome being written to: "smartroi_params_28_1.mzML"
# Outcome being written to: "smartroi_params_46_1.mzML"
# Outcome being written to: "smartroi_params_32_1.mzML"
# Outcome being written to: "smartroi_params_40_1.mzML"
# Outcome being written to: "topN_params_21_3.mzML"
# Outcome being written to: "smartroi_params_68_1.mzML"
# Outcome being written to: "smartroi_params_26_1.mzML"
# Outcome being written to: "smartroi_params_58_1.mzML"
# Outcome being written to: "topN_params_11_3.mzML"
# Outcome being written to: "smartroi_params_8_1.mzML"
# Outcome being written to: "smartroi_params_2_1.mzML"
# Outcome being written to: "smartroi_params_30_1.mzML"
# Outcome being written to: "topN_params_17_3.mzML"
# Outcome being written to: "smartroi_params_24_1.mzML"
# Outcome being written to: "smartroi_params_6_1.mzML"
# Outcome being written to: "topN_params_13_2.mzML"
# Outcome being written to: "smartroi_params_42_1.mzML"
# Outcome being written to: "smartroi_params_10_1.mzML"
# Outcome being written to: "smartroi_params_12_1.mzML"
# Outcome being written to: "smartroi_params_62_1.mzML"
# Outcome being written to: "smartroi_params_66_2.mzML"
# Outcome being written to: "topN_params_1_2.mzML"
# Outcome being written to: "smartroi_params_36_1.mzML"
# Outcome being written to: "smartroi_params_38_1.mzML"
# Outcome being written to: "smartroi_params_50_1.mzML"
# Outcome being written to: "smartroi_params_70_2.mzML"
# Outcome being written to: "topN_params_7_2.mzML"
# Outcome being written to: "smartroi_params_60_1.mzML"
# Outcome being written to: "smartroi_params_48_1.mzML"
# Outcome being written to: "topN_params_19_2.mzML"
# Outcome being written to: "topN_params_15_2.mzML"
# Outcome being written to: "smartroi_params_56_2.mzML"
# Outcome being written to: "smartroi_params_0_2.mzML"
# Outcome being written to: "topN_params_23_3.mzML"
# Outcome being written to: "smartroi_params_14_1.mzML"
# Outcome being written to: "smartroi_params_20_1.mzML"
# Outcome being written to: "topN_params_5_2.mzML"
# Outcome being written to: "topN_params_3_2.mzML"
# Outcome being written to: "smartroi_params_34_2.mzML"
# Outcome being written to: "smartroi_params_52_2.mzML"
# Outcome being written to: "smartroi_params_4_1.mzML"
# Outcome being written to: "smartroi_params_44_2.mzML"
# Outcome being written to: "smartroi_params_64_2.mzML"
# Outcome being written to: "smartroi_params_54_2.mzML"
# Outcome being written to: "smartroi_params_18_2.mzML"
# Outcome being written to: "topN_params_9_2.mzML"
# Outcome being written to: "smartroi_params_22_2.mzML"
# Outcome being written to: "smartroi_params_16_1.mzML"
# Outcome being written to: "smartroi_params_28_2.mzML"
# Outcome being written to: "topN_params_21_4.mzML"
# Outcome being written to: "smartroi_params_46_2.mzML"
# Outcome being written to: "smartroi_params_32_2.mzML"
# Outcome being written to: "smartroi_params_40_2.mzML"
# Outcome being written to: "topN_params_11_4.mzML"
# Outcome being written to: "smartroi_params_58_2.mzML"
# Outcome being written to: "smartroi_params_26_2.mzML"
# Outcome being written to: "topN_params_17_4.mzML"
# Outcome being written to: "smartroi_params_30_2.mzML"
# Outcome being written to: "smartroi_params_2_2.mzML"
# Outcome being written to: "smartroi_params_8_2.mzML"
# Outcome being written to: "smartroi_params_68_2.mzML"
# Outcome being written to: "topN_params_13_3.mzML"
# Outcome being written to: "smartroi_params_6_2.mzML"
# Outcome being written to: "smartroi_params_66_3.mzML"
# Outcome being written to: "topN_params_1_3.mzML"
# Outcome being written to: "topN_params_15_3.mzML"
# Outcome being written to: "smartroi_params_10_2.mzML"
# Outcome being written to: "smartroi_params_24_2.mzML"
# Outcome being written to: "smartroi_params_12_2.mzML"
# Outcome being written to: "smartroi_params_62_2.mzML"
# Outcome being written to: "smartroi_params_50_2.mzML"
# Outcome being written to: "smartroi_params_70_3.mzML"
# Outcome being written to: "smartroi_params_48_2.mzML"
# Outcome being written to: "smartroi_params_42_2.mzML"
# Outcome being written to: "smartroi_params_38_2.mzML"
# Outcome being written to: "smartroi_params_36_2.mzML"
# Outcome being written to: "topN_params_7_3.mzML"
# Outcome being written to: "topN_params_5_3.mzML"
# Outcome being written to: "smartroi_params_60_2.mzML"
# Outcome being written to: "topN_params_23_4.mzML"
# Outcome being written to: "topN_params_19_3.mzML"
# Outcome being written to: "smartroi_params_56_3.mzML"
# Outcome being written to: "smartroi_params_0_3.mzML"
# Outcome being written to: "smartroi_params_20_2.mzML"
# Outcome being written to: "topN_params_3_3.mzML"
# Outcome being written to: "smartroi_params_34_3.mzML"
# Outcome being written to: "smartroi_params_14_2.mzML"
# Outcome being written to: "smartroi_params_64_3.mzML"
# Outcome being written to: "smartroi_params_4_2.mzML"
# Outcome being written to: "smartroi_params_44_3.mzML"
# Outcome being written to: "smartroi_params_18_3.mzML"
# Outcome being written to: "topN_params_21_5.mzML"
# Outcome being written to: "smartroi_params_52_3.mzML"
# Outcome being written to: "smartroi_params_22_3.mzML"
# Outcome being written to: "smartroi_params_16_2.mzML"
# Outcome being written to: "topN_params_11_5.mzML"
# Outcome being written to: "smartroi_params_54_3.mzML"
# Outcome being written to: "smartroi_params_46_3.mzML"
# Outcome being written to: "smartroi_params_32_3.mzML"
# Outcome being written to: "smartroi_params_28_3.mzML"
# Outcome being written to: "topN_params_9_3.mzML"
# Outcome being written to: "topN_params_17_5.mzML"
# Outcome being written to: "topN_params_15_4.mzML"
# Outcome being written to: "smartroi_params_58_3.mzML"
# Outcome being written to: "smartroi_params_40_3.mzML"
# Outcome being written to: "smartroi_params_26_3.mzML"
# Outcome being written to: "topN_params_13_4.mzML"
# Outcome being written to: "smartroi_params_30_3.mzML"
# Outcome being written to: "smartroi_params_66_4.mzML"
# Outcome being written to: "smartroi_params_2_3.mzML"
# Outcome being written to: "topN_params_1_4.mzML"
# Outcome being written to: "smartroi_params_68_3.mzML"
# Outcome being written to: "smartroi_params_8_3.mzML"
# Outcome being written to: "topN_params_5_4.mzML"
# Outcome being written to: "smartroi_params_6_3.mzML"
# Outcome being written to: "smartroi_params_70_4.mzML"
# Outcome being written to: "smartroi_params_10_3.mzML"
# Outcome being written to: "smartroi_params_12_3.mzML"
# Outcome being written to: "smartroi_params_24_3.mzML"
# Outcome being written to: "smartroi_params_62_3.mzML"
# Outcome being written to: "smartroi_params_50_3.mzML"
# Outcome being written to: "smartroi_params_48_3.mzML"
# Outcome being written to: "smartroi_params_36_3.mzML"
# Outcome being written to: "topN_params_23_5.mzML"
# Outcome being written to: "topN_params_7_4.mzML"
# Outcome being written to: "smartroi_params_56_4.mzML"
# Outcome being written to: "smartroi_params_38_3.mzML"
# Outcome being written to: "smartroi_params_42_3.mzML"
# Outcome being written to: "topN_params_19_4.mzML"
# Outcome being written to: "smartroi_params_60_3.mzML"
# Outcome being written to: "smartroi_params_0_4.mzML"
# Outcome being written to: "smartroi_params_34_4.mzML"
# Outcome being written to: "topN_params_3_4.mzML"
# Outcome being written to: "smartroi_params_64_4.mzML"
# Outcome being written to: "smartroi_params_44_4.mzML"
# Outcome being written to: "smartroi_params_20_3.mzML"
# Outcome being written to: "smartroi_params_18_4.mzML"
# Outcome being written to: "topN_params_15_5.mzML"
# Outcome being written to: "smartroi_params_4_3.mzML"
# Outcome being written to: "smartroi_params_73_0.mzML"
# Outcome being written to: "smartroi_params_54_4.mzML"
# Outcome being written to: "smartroi_params_22_4.mzML"
# Outcome being written to: "smartroi_params_32_4.mzML"
# Outcome being written to: "smartroi_params_46_4.mzML"
# Outcome being written to: "smartroi_params_71_0.mzML"
# Outcome being written to: "smartroi_params_16_3.mzML"
# Outcome being written to: "smartroi_params_14_3.mzML"
# Outcome being written to: "smartroi_params_28_4.mzML"
# Outcome being written to: "topN_params_9_4.mzML"
# Outcome being written to: "smartroi_params_75_0.mzML"
# Outcome being written to: "smartroi_params_52_4.mzML"
# Outcome being written to: "smartroi_params_58_4.mzML"
# Outcome being written to: "smartroi_params_26_4.mzML"
# Outcome being written to: "topN_params_13_5.mzML"
# Outcome being written to: "topN_params_5_5.mzML"
# Outcome being written to: "smartroi_params_40_4.mzML"
# Outcome being written to: "smartroi_params_30_4.mzML"
# Outcome being written to: "topN_params_1_5.mzML"
# Outcome being written to: "smartroi_params_66_5.mzML"
# Outcome being written to: "smartroi_params_2_4.mzML"
# Outcome being written to: "smartroi_params_70_5.mzML"
# Outcome being written to: "smartroi_params_68_4.mzML"
# Outcome being written to: "smartroi_params_6_4.mzML"
# Outcome being written to: "smartroi_params_8_4.mzML"
# Outcome being written to: "smartroi_params_10_4.mzML"
# Outcome being written to: "smartroi_params_48_4.mzML"
# Outcome being written to: "smartroi_params_50_4.mzML"
# Outcome being written to: "smartroi_params_24_4.mzML"
# Outcome being written to: "smartroi_params_12_4.mzML"
# Outcome being written to: "smartroi_params_36_4.mzML"
# Outcome being written to: "smartroi_params_62_4.mzML"
# Outcome being written to: "smartroi_params_38_4.mzML"
# Outcome being written to: "smartroi_params_56_5.mzML"
# Outcome being written to: "smartroi_params_77_0.mzML"
# Outcome being written to: "topN_params_19_5.mzML"
# Outcome being written to: "topN_params_7_5.mzML"
# Outcome being written to: "smartroi_params_42_4.mzML"
# Outcome being written to: "smartroi_params_79_0.mzML"
# Outcome being written to: "smartroi_params_0_5.mzML"
# Outcome being written to: "smartroi_params_60_4.mzML"
# Outcome being written to: "topN_params_3_5.mzML"
# Outcome being written to: "smartroi_params_34_5.mzML"
# Outcome being written to: "smartroi_params_73_1.mzML"
# Outcome being written to: "smartroi_params_64_5.mzML"
# Outcome being written to: "smartroi_params_18_5.mzML"
# Outcome being written to: "smartroi_params_71_1.mzML"
# Outcome being written to: "smartroi_params_75_1.mzML"
# Outcome being written to: "smartroi_params_44_5.mzML"
# Outcome being written to: "smartroi_params_4_4.mzML"
# Outcome being written to: "smartroi_params_20_4.mzML"
# Outcome being written to: "smartroi_params_54_5.mzML"
# Outcome being written to: "smartroi_params_22_5.mzML"
# Outcome being written to: "smartroi_params_16_4.mzML"
# Outcome being written to: "smartroi_params_32_5.mzML"
# Outcome being written to: "smartroi_params_46_5.mzML"
# Outcome being written to: "topN_params_9_5.mzML"
# Outcome being written to: "weighteddew_params_1_0.mzML"
# Outcome being written to: "smartroi_params_28_5.mzML"
# Outcome being written to: "smartroi_params_58_5.mzML"
# Outcome being written to: "smartroi_params_14_4.mzML"
# Outcome being written to: "smartroi_params_26_5.mzML"
# Outcome being written to: "smartroi_params_52_5.mzML"
# Outcome being written to: "smartroi_params_40_5.mzML"
# Outcome being written to: "weighteddew_params_10_0.mzML"
# Outcome being written to: "smartroi_params_30_5.mzML"
# Outcome being written to: "weighteddew_params_6_0.mzML"
# Outcome being written to: "weighteddew_params_12_0.mzML"
# Outcome being written to: "smartroi_params_77_1.mzML"
# Outcome being written to: "smartroi_params_2_5.mzML"
# Outcome being written to: "smartroi_params_6_5.mzML"
# Outcome being written to: "smartroi_params_8_5.mzML"
# Outcome being written to: "smartroi_params_10_5.mzML"
# Outcome being written to: "smartroi_params_50_5.mzML"
# Outcome being written to: "weighteddew_params_15_0.mzML"
# Outcome being written to: "smartroi_params_68_5.mzML"
# Outcome being written to: "smartroi_params_48_5.mzML"
# Outcome being written to: "smartroi_params_24_5.mzML"
# Outcome being written to: "smartroi_params_36_5.mzML"
# Outcome being written to: "smartroi_params_12_5.mzML"
# Outcome being written to: "smartroi_params_79_1.mzML"
# Outcome being written to: "smartroi_params_38_5.mzML"
# Outcome being written to: "smartroi_params_73_2.mzML"
# Outcome being written to: "weighteddew_params_17_0.mzML"
# Outcome being written to: "smartroi_params_62_5.mzML"
# Outcome being written to: "smartroi_params_75_2.mzML"
# Outcome being written to: "weighteddew_params_19_0.mzML"
# Outcome being written to: "weighteddew_params_21_0.mzML"
# Outcome being written to: "smartroi_params_71_2.mzML"
# Outcome being written to: "smartroi_params_42_5.mzML"
# Outcome being written to: "weighteddew_params_25_0.mzML"
# Outcome being written to: "smartroi_params_60_5.mzML"
# Outcome being written to: "weighteddew_params_30_0.mzML"
# Outcome being written to: "weighteddew_params_23_0.mzML"
# Outcome being written to: "weighteddew_params_32_0.mzML"
# Outcome being written to: "smartroi_params_4_5.mzML"
# Outcome being written to: "weighteddew_params_36_0.mzML"
# Outcome being written to: "smartroi_params_16_5.mzML"
# Outcome being written to: "weighteddew_params_1_1.mzML"
# Outcome being written to: "weighteddew_params_38_0.mzML"
# Outcome being written to: "weighteddew_params_41_0.mzML"
# Outcome being written to: "smartroi_params_20_5.mzML"
# Outcome being written to: "weighteddew_params_10_1.mzML"
# Outcome being written to: "weighteddew_params_45_0.mzML"
# Outcome being written to: "smartroi_params_77_2.mzML"
# Outcome being written to: "weighteddew_params_47_0.mzML"
# Outcome being written to: "weighteddew_params_43_0.mzML"
# Outcome being written to: "weighteddew_params_6_1.mzML"
# Outcome being written to: "weighteddew_params_12_1.mzML"
# Outcome being written to: "weighteddew_params_49_0.mzML"
# Outcome being written to: "weighteddew_params_51_0.mzML"
# Outcome being written to: "weighteddew_params_56_0.mzML"
# Outcome being written to: "smartroi_params_79_2.mzML"
# Outcome being written to: "weighteddew_params_60_0.mzML"
# Outcome being written to: "smartroi_params_14_5.mzML"
# Outcome being written to: "weighteddew_params_15_1.mzML"
# Outcome being written to: "weighteddew_params_65_0.mzML"
# Outcome being written to: "weighteddew_params_67_0.mzML"
# Outcome being written to: "weighteddew_params_62_0.mzML"
# Outcome being written to: "smartroi_params_73_3.mzML"
# Outcome being written to: "weighteddew_params_69_0.mzML"
# Outcome being written to: "weighteddew_params_71_0.mzML"
# Outcome being written to: "weighteddew_params_75_0.mzML"
# Outcome being written to: "weighteddew_params_80_0.mzML"
# Outcome being written to: "weighteddew_params_73_0.mzML"
# Outcome being written to: "weighteddew_params_17_1.mzML"
# Outcome being written to: "weighteddew_params_82_0.mzML"
# Outcome being written to: "smartroi_params_75_3.mzML"
# Outcome being written to: "weighteddew_params_91_0.mzML"
# Outcome being written to: "weighteddew_params_88_0.mzML"
# Outcome being written to: "weighteddew_params_93_0.mzML"
# Outcome being written to: "weighteddew_params_86_0.mzML"
# Outcome being written to: "weighteddew_params_30_1.mzML"
# Outcome being written to: "weighteddew_params_32_1.mzML"
# Outcome being written to: "weighteddew_params_25_1.mzML"
# Outcome being written to: "weighteddew_params_95_0.mzML"
# Outcome being written to: "weighteddew_params_21_1.mzML"
# Outcome being written to: "smartroi_params_71_3.mzML"
# Outcome being written to: "weighteddew_params_23_1.mzML"
# Outcome being written to: "weighteddew_params_36_1.mzML"
# Outcome being written to: "weighteddew_params_19_1.mzML"
# Outcome being written to: "weighteddew_params_38_1.mzML"
# Outcome being written to: "weighteddew_params_41_1.mzML"
# Outcome being written to: "weighteddew_params_97_0.mzML"
# Outcome being written to: "weighteddew_params_1_2.mzML"
# Outcome being written to: "weighteddew_params_45_1.mzML"
# Outcome being written to: "weighteddew_params_47_1.mzML"
# Outcome being written to: "weighteddew_params_51_1.mzML"
# Outcome being written to: "weighteddew_params_43_1.mzML"
# Outcome being written to: "weighteddew_params_56_1.mzML"
# Outcome being written to: "smartroi_params_77_3.mzML"
# Outcome being written to: "weighteddew_params_60_1.mzML"
# Outcome being written to: "weighteddew_params_10_2.mzML"
# Outcome being written to: "weighteddew_params_6_2.mzML"
# Outcome being written to: "weighteddew_params_12_2.mzML"
# Outcome being written to: "weighteddew_params_99_0.mzML"
# Outcome being written to: "weighteddew_params_49_1.mzML"
# Outcome being written to: "weighteddew_params_110_0.mzML"
# Outcome being written to: "weighteddew_params_65_1.mzML"
# Outcome being written to: "weighteddew_params_75_1.mzML"
# Outcome being written to: "weighteddew_params_106_0.mzML"
# Outcome being written to: "weighteddew_params_101_0.mzML"
# Outcome being written to: "weighteddew_params_67_1.mzML"
# Outcome being written to: "weighteddew_params_80_1.mzML"
# Outcome being written to: "smartroi_params_79_3.mzML"
# Outcome being written to: "weighteddew_params_82_1.mzML"
# Outcome being written to: "weighteddew_params_71_1.mzML"
# Outcome being written to: "weighteddew_params_62_1.mzML"
# Outcome being written to: "weighteddew_params_86_1.mzML"
# Outcome being written to: "weighteddew_params_15_2.mzML"
# Outcome being written to: "weighteddew_params_91_1.mzML"
# Outcome being written to: "weighteddew_params_73_1.mzML"
# Outcome being written to: "weighteddew_params_69_1.mzML"
# Outcome being written to: "weighteddew_params_95_1.mzML"
# Outcome being written to: "weighteddew_params_88_1.mzML"
# Outcome being written to: "smartroi_params_73_4.mzML"
# Outcome being written to: "weighteddew_params_112_0.mzML"
# Outcome being written to: "weighteddew_params_93_1.mzML"
# Outcome being written to: "smartroi_params_75_4.mzML"
# Outcome being written to: "weighteddew_params_30_2.mzML"
# Outcome being written to: "weighteddew_params_17_2.mzML"
# Outcome being written to: "weighteddew_params_25_2.mzML"
# Outcome being written to: "weighteddew_params_32_2.mzML"
# Outcome being written to: "weighteddew_params_36_2.mzML"
# Outcome being written to: "weighteddew_params_115_0.mzML"
# Outcome being written to: "weighteddew_params_21_2.mzML"
# Outcome being written to: "weighteddew_params_23_2.mzML"
# Outcome being written to: "weighteddew_params_97_1.mzML"
# Outcome being written to: "weighteddew_params_110_1.mzML"
# Outcome being written to: "smartroi_params_71_4.mzML"
# Outcome being written to: "weighteddew_params_38_2.mzML"
# Outcome being written to: "weighteddew_params_41_2.mzML"
# Outcome being written to: "weighteddew_params_106_1.mzML"
# Outcome being written to: "weighteddew_params_56_2.mzML"
# Outcome being written to: "weighteddew_params_45_2.mzML"
# Outcome being written to: "weighteddew_params_51_2.mzML"
# Outcome being written to: "weighteddew_params_101_1.mzML"
# Outcome being written to: "weighteddew_params_47_2.mzML"
# Outcome being written to: "weighteddew_params_60_2.mzML"
# Outcome being written to: "weighteddew_params_19_2.mzML"
# Outcome being written to: "weighteddew_params_43_2.mzML"
# Outcome being written to: "weighteddew_params_75_2.mzML"
# Outcome being written to: "weighteddew_params_80_2.mzML"
# Outcome being written to: "weighteddew_params_1_3.mzML"
# Outcome being written to: "weighteddew_params_82_2.mzML"
# Outcome being written to: "weighteddew_params_65_2.mzML"
# Outcome being written to: "weighteddew_params_67_2.mzML"
# Outcome being written to: "smartroi_params_77_4.mzML"
# Outcome being written to: "weighteddew_params_86_2.mzML"
# Outcome being written to: "weighteddew_params_99_1.mzML"
# Outcome being written to: "weighteddew_params_71_2.mzML"
# Outcome being written to: "weighteddew_params_49_2.mzML"
# Outcome being written to: "weighteddew_params_6_3.mzML"
# Outcome being written to: "weighteddew_params_12_3.mzML"
# Outcome being written to: "weighteddew_params_10_3.mzML"
# Outcome being written to: "weighteddew_params_95_2.mzML"
# Outcome being written to: "weighteddew_params_112_1.mzML"
# Outcome being written to: "smartroi_params_79_4.mzML"
# Outcome being written to: "weighteddew_params_91_2.mzML"
# Outcome being written to: "weighteddew_params_88_2.mzML"
# Outcome being written to: "weighteddew_params_62_2.mzML"
# Outcome being written to: "weighteddew_params_73_2.mzML"
# Outcome being written to: "weighteddew_params_93_2.mzML"
# Outcome being written to: "weighteddew_params_69_2.mzML"
# Outcome being written to: "weighteddew_params_115_1.mzML"
# Outcome being written to: "weighteddew_params_15_3.mzML"
# Outcome being written to: "weighteddew_params_30_3.mzML"
# Outcome being written to: "weighteddew_params_110_2.mzML"
# Outcome being written to: "weighteddew_params_25_3.mzML"
# Outcome being written to: "weighteddew_params_106_2.mzML"
# Outcome being written to: "smartroi_params_73_5.mzML"
# Outcome being written to: "weighteddew_params_32_3.mzML"
# Outcome being written to: "smartroi_params_75_5.mzML"
# Outcome being written to: "weighteddew_params_36_3.mzML"
# Outcome being written to: "weighteddew_params_17_3.mzML"
# Outcome being written to: "weighteddew_params_101_2.mzML"
# Outcome being written to: "weighteddew_params_97_2.mzML"
# Outcome being written to: "weighteddew_params_80_3.mzML"
# Outcome being written to: "weighteddew_params_56_3.mzML"
# Outcome being written to: "weighteddew_params_75_3.mzML"
# Outcome being written to: "weighteddew_params_51_3.mzML"
# Outcome being written to: "weighteddew_params_41_3.mzML"
# Outcome being written to: "weighteddew_params_38_3.mzML"
# Outcome being written to: "weighteddew_params_60_3.mzML"
# Outcome being written to: "weighteddew_params_45_3.mzML"
# Outcome being written to: "weighteddew_params_82_3.mzML"
# Outcome being written to: "weighteddew_params_86_3.mzML"
# Outcome being written to: "weighteddew_params_23_3.mzML"
# Outcome being written to: "weighteddew_params_47_3.mzML"
# Outcome being written to: "weighteddew_params_21_3.mzML"
# Outcome being written to: "smartroi_params_71_5.mzML"
# Outcome being written to: "weighteddew_params_95_3.mzML"
# Outcome being written to: "weighteddew_params_43_3.mzML"
# Outcome being written to: "weighteddew_params_65_3.mzML"
# Outcome being written to: "weighteddew_params_67_3.mzML"
# Outcome being written to: "weighteddew_params_71_3.mzML"
# Outcome being written to: "weighteddew_params_1_4.mzML"
# Outcome being written to: "weighteddew_params_112_2.mzML"
# Outcome being written to: "weighteddew_params_91_3.mzML"
# Outcome being written to: "weighteddew_params_115_2.mzML"
# Outcome being written to: "weighteddew_params_110_3.mzML"
# Outcome being written to: "weighteddew_params_99_2.mzML"
# Outcome being written to: "weighteddew_params_19_3.mzML"
# Outcome being written to: "smartroi_params_77_5.mzML"
# Outcome being written to: "weighteddew_params_88_3.mzML"
# Outcome being written to: "weighteddew_params_106_3.mzML"
# Outcome being written to: "weighteddew_params_12_4.mzML"
# Outcome being written to: "weighteddew_params_93_3.mzML"
# Outcome being written to: "weighteddew_params_6_4.mzML"
# Outcome being written to: "weighteddew_params_49_3.mzML"
# Outcome being written to: "weighteddew_params_10_4.mzML"
# Outcome being written to: "weighteddew_params_62_3.mzML"
# Outcome being written to: "weighteddew_params_73_3.mzML"
# Outcome being written to: "smartroi_params_79_5.mzML"
# Outcome being written to: "weighteddew_params_69_3.mzML"
# Outcome being written to: "weighteddew_params_30_4.mzML"
# Outcome being written to: "weighteddew_params_101_3.mzML"
# Outcome being written to: "weighteddew_params_25_4.mzML"
# Outcome being written to: "weighteddew_params_80_4.mzML"
# Outcome being written to: "weighteddew_params_75_4.mzML"
# Outcome being written to: "weighteddew_params_15_4.mzML"
# Outcome being written to: "weighteddew_params_32_4.mzML"
# Outcome being written to: "weighteddew_params_36_4.mzML"
# Outcome being written to: "weighteddew_params_56_4.mzML"
# Outcome being written to: "weighteddew_params_97_3.mzML"
# Outcome being written to: "weighteddew_params_82_4.mzML"
# Outcome being written to: "weighteddew_params_51_4.mzML"
# Outcome being written to: "weighteddew_params_86_4.mzML"
# Outcome being written to: "weighteddew_params_60_4.mzML"
# Outcome being written to: "weighteddew_params_17_4.mzML"
# Outcome being written to: "weighteddew_params_41_4.mzML"
# Outcome being written to: "smartroi_params_76_0.mzML"
# Outcome being written to: "weighteddew_params_95_4.mzML"
# Outcome being written to: "smartroi_params_74_0.mzML"
# Outcome being written to: "weighteddew_params_38_4.mzML"
# Outcome being written to: "weighteddew_params_45_4.mzML"
# Outcome being written to: "weighteddew_params_110_4.mzML"
# Outcome being written to: "weighteddew_params_115_3.mzML"
# Outcome being written to: "weighteddew_params_65_4.mzML"
# Outcome being written to: "weighteddew_params_47_4.mzML"
# Outcome being written to: "weighteddew_params_112_3.mzML"
# Outcome being written to: "weighteddew_params_106_4.mzML"
# Outcome being written to: "weighteddew_params_67_4.mzML"
# Outcome being written to: "weighteddew_params_23_4.mzML"
# Outcome being written to: "weighteddew_params_71_4.mzML"
# Outcome being written to: "weighteddew_params_43_4.mzML"
# Outcome being written to: "weighteddew_params_91_4.mzML"
# Outcome being written to: "weighteddew_params_21_4.mzML"
# Outcome being written to: "weighteddew_params_88_4.mzML"
# Outcome being written to: "weighteddew_params_1_5.mzML"
# Outcome being written to: "weighteddew_params_93_4.mzML"
# Outcome being written to: "weighteddew_params_101_4.mzML"
# Outcome being written to: "smartroi_params_72_0.mzML"
# Outcome being written to: "weighteddew_params_99_3.mzML"
# Outcome being written to: "weighteddew_params_80_5.mzML"
# Outcome being written to: "weighteddew_params_75_5.mzML"
# Outcome being written to: "weighteddew_params_49_4.mzML"
# Outcome being written to: "weighteddew_params_73_4.mzML"
# Outcome being written to: "weighteddew_params_6_5.mzML"
# Outcome being written to: "weighteddew_params_62_4.mzML"
# Outcome being written to: "weighteddew_params_12_5.mzML"
# Outcome being written to: "weighteddew_params_69_4.mzML"
# Outcome being written to: "weighteddew_params_30_5.mzML"
# Outcome being written to: "weighteddew_params_10_5.mzML"
# Outcome being written to: "smartroi_params_78_0.mzML"
# Outcome being written to: "weighteddew_params_19_4.mzML"
# Outcome being written to: "weighteddew_params_25_5.mzML"
# Outcome being written to: "weighteddew_params_82_5.mzML"
# Outcome being written to: "weighteddew_params_0_0.mzML"
# Outcome being written to: "weighteddew_params_56_5.mzML"
# Outcome being written to: "weighteddew_params_97_4.mzML"
# Outcome being written to: "weighteddew_params_32_5.mzML"
# Outcome being written to: "weighteddew_params_86_5.mzML"
# Outcome being written to: "weighteddew_params_110_5.mzML"
# Outcome being written to: "weighteddew_params_51_5.mzML"
# Outcome being written to: "weighteddew_params_60_5.mzML"
# Outcome being written to: "weighteddew_params_36_5.mzML"
# Outcome being written to: "weighteddew_params_115_4.mzML"
# Outcome being written to: "weighteddew_params_95_5.mzML"
# Outcome being written to: "weighteddew_params_15_5.mzML"
# Outcome being written to: "smartroi_params_74_1.mzML"
# Outcome being written to: "smartroi_params_76_1.mzML"
# Outcome being written to: "weighteddew_params_106_5.mzML"
# Outcome being written to: "weighteddew_params_112_4.mzML"
# Outcome being written to: "weighteddew_params_41_5.mzML"
# Outcome being written to: "weighteddew_params_45_5.mzML"
# Outcome being written to: "weighteddew_params_38_5.mzML"
# Outcome being written to: "weighteddew_params_65_5.mzML"
# Outcome being written to: "weighteddew_params_17_5.mzML"
# Outcome being written to: "weighteddew_params_67_5.mzML"
# Outcome being written to: "weighteddew_params_47_5.mzML"
# Outcome being written to: "weighteddew_params_71_5.mzML"
# Outcome being written to: "weighteddew_params_91_5.mzML"
# Outcome being written to: "weighteddew_params_101_5.mzML"
# Outcome being written to: "weighteddew_params_23_5.mzML"
# Outcome being written to: "weighteddew_params_43_5.mzML"
# Outcome being written to: "weighteddew_params_76_0.mzML"
# Outcome being written to: "weighteddew_params_81_0.mzML"
# Outcome being written to: "weighteddew_params_88_5.mzML"
# Outcome being written to: "weighteddew_params_93_5.mzML"
# Outcome being written to: "weighteddew_params_21_5.mzML"
# Outcome being written to: "smartroi_params_72_1.mzML"
# Outcome being written to: "weighteddew_params_5_0.mzML"
# Outcome being written to: "weighteddew_params_111_0.mzML"
# Outcome being written to: "smartroi_params_78_1.mzML"
# Outcome being written to: "weighteddew_params_99_4.mzML"
# Outcome being written to: "weighteddew_params_73_5.mzML"
# Outcome being written to: "weighteddew_params_31_0.mzML"
# Outcome being written to: "weighteddew_params_85_0.mzML"
# Outcome being written to: "weighteddew_params_62_5.mzML"
# Outcome being written to: "weighteddew_params_49_5.mzML"
# Outcome being written to: "weighteddew_params_115_5.mzML"
# Outcome being written to: "weighteddew_params_87_0.mzML"
# Outcome being written to: "weighteddew_params_107_0.mzML"
# Outcome being written to: "weighteddew_params_69_5.mzML"
# Outcome being written to: "weighteddew_params_7_0.mzML"
# Outcome being written to: "weighteddew_params_57_0.mzML"
# Outcome being written to: "weighteddew_params_13_0.mzML"
# ...
# Outcome being written to: "smartroi_params_72_2.mzML"
# Outcome being written to: "weighteddew_params_22_0.mzML"
# Outcome being written to: "weighteddew_params_61_1.mzML"
# Outcome being written to: "weighteddew_params_26_1.mzML"
# Outcome being written to: "weighteddew_params_55_1.mzML"
# Outcome being written to: "weighteddew_params_74_0.mzML"
# Outcome being written to: "weighteddew_params_99_5.mzML"
# Outcome being written to: "weighteddew_params_7_1.mzML"
# Outcome being written to: "weighteddew_params_35_1.mzML"
# Outcome being written to: "weighteddew_params_13_1.mzML"
# Outcome being written to: "weighteddew_params_63_0.mzML"
# Outcome being written to: "weighteddew_params_105_1.mzML"
# Outcome being written to: "weighteddew_params_37_1.mzML"
# Outcome being written to: "weighteddew_params_11_1.mzML"
# Outcome being written to: "weighteddew_params_98_0.mzML"
# Outcome being written to: "weighteddew_params_70_0.mzML"
# Outcome being written to: "smartroi_params_74_3.mzML"
# Outcome being written to: "weighteddew_params_113_0.mzML"
# Outcome being written to: "weighteddew_params_81_2.mzML"
# Outcome being written to: "weighteddew_params_50_0.mzML"
# Outcome being written to: "weighteddew_params_66_1.mzML"
# Outcome being written to: "weighteddew_params_0_2.mzML"
# Outcome being written to: "weighteddew_params_111_2.mzML"
# Outcome being written to: "weighteddew_params_76_2.mzML"
# Outcome being written to: "smartroi_params_76_3.mzML"
# Outcome being written to: "weighteddew_params_72_1.mzML"
# Outcome being written to: "weighteddew_params_42_1.mzML"
# Outcome being written to: "weighteddew_params_46_1.mzML"
# Outcome being written to: "weighteddew_params_92_1.mzML"
# Outcome being written to: "weighteddew_params_68_1.mzML"
# Outcome being written to: "weighteddew_params_40_1.mzML"
# Outcome being written to: "weighteddew_params_90_1.mzML"
# Outcome being written to: "weighteddew_params_16_1.mzML"
# Outcome being written to: "weighteddew_params_85_2.mzML"
# Outcome being written to: "weighteddew_params_48_1.mzML"
# Outcome being written to: "weighteddew_params_107_2.mzML"
# Outcome being written to: "weighteddew_params_116_1.mzML"
# Outcome being written to: "weighteddew_params_96_2.mzML"
# Outcome being written to: "weighteddew_params_87_2.mzML"
# Outcome being written to: "weighteddew_params_20_0.mzML"
# Outcome being written to: "weighteddew_params_94_1.mzML"
# Outcome being written to: "weighteddew_params_18_1.mzML"
# Outcome being written to: "weighteddew_params_31_2.mzML"
# Outcome being written to: "weighteddew_params_57_2.mzML"
# Outcome being written to: "weighteddew_params_44_1.mzML"
# Outcome being written to: "weighteddew_params_61_2.mzML"
# Outcome being written to: "weighteddew_params_24_1.mzML"
# Outcome being written to: "smartroi_params_78_3.mzML"
# Outcome being written to: "weighteddew_params_5_2.mzML"
# Outcome being written to: "weighteddew_params_55_2.mzML"
# Outcome being written to: "weighteddew_params_105_2.mzML"
# Outcome being written to: "weighteddew_params_111_3.mzML"
# Outcome being written to: "weighteddew_params_81_3.mzML"
# Outcome being written to: "weighteddew_params_74_1.mzML"
# Outcome being written to: "weighteddew_params_26_2.mzML"
# Outcome being written to: "weighteddew_params_22_1.mzML"
# Outcome being written to: "weighteddew_params_76_3.mzML"
# Outcome being written to: "weighteddew_params_70_1.mzML"
# Outcome being written to: "weighteddew_params_113_1.mzML"
# Outcome being written to: "weighteddew_params_35_2.mzML"
# Outcome being written to: "weighteddew_params_37_2.mzML"
# Outcome being written to: "weighteddew_params_98_1.mzML"
# Outcome being written to: "smartroi_params_72_3.mzML"
# Outcome being written to: "weighteddew_params_7_2.mzML"
# Outcome being written to: "weighteddew_params_63_1.mzML"
# Outcome being written to: "weighteddew_params_50_1.mzML"
# Outcome being written to: "weighteddew_params_13_2.mzML"
# Outcome being written to: "weighteddew_params_66_2.mzML"
# Outcome being written to: "weighteddew_params_11_2.mzML"
# Outcome being written to: "weighteddew_params_72_2.mzML"
# Outcome being written to: "smartroi_params_74_4.mzML"
# Outcome being written to: "weighteddew_params_90_2.mzML"
# Outcome being written to: "weighteddew_params_85_3.mzML"
# Outcome being written to: "weighteddew_params_42_2.mzML"
# Outcome being written to: "weighteddew_params_107_3.mzML"
# Outcome being written to: "weighteddew_params_68_2.mzML"
# Outcome being written to: "weighteddew_params_40_2.mzML"
# Outcome being written to: "smartroi_params_76_4.mzML"
# Outcome being written to: "weighteddew_params_92_2.mzML"
# Outcome being written to: "weighteddew_params_0_3.mzML"
# Outcome being written to: "weighteddew_params_100_0.mzML"
# Outcome being written to: "weighteddew_params_46_2.mzML"
# Outcome being written to: "weighteddew_params_96_3.mzML"
# Outcome being written to: "weighteddew_params_116_2.mzML"
# Outcome being written to: "weighteddew_params_87_3.mzML"
# Outcome being written to: "weighteddew_params_16_2.mzML"
# Outcome being written to: "weighteddew_params_48_2.mzML"
# Outcome being written to: "weighteddew_params_94_2.mzML"
# Outcome being written to: "weighteddew_params_105_3.mzML"
# Outcome being written to: "weighteddew_params_57_3.mzML"
# Outcome being written to: "weighteddew_params_111_4.mzML"
# Outcome being written to: "weighteddew_params_31_3.mzML"
# Outcome being written to: "weighteddew_params_18_2.mzML"
# Outcome being written to: "weighteddew_params_61_3.mzML"
# Outcome being written to: "weighteddew_params_81_4.mzML"
# Outcome being written to: "weighteddew_params_20_1.mzML"
# Outcome being written to: "weighteddew_params_44_2.mzML"
# Outcome being written to: "weighteddew_params_76_4.mzML"
# Outcome being written to: "weighteddew_params_55_3.mzML"
# Outcome being written to: "weighteddew_params_24_2.mzML"
# Outcome being written to: "smartroi_params_78_4.mzML"
# Outcome being written to: "weighteddew_params_70_2.mzML"
# Outcome being written to: "weighteddew_params_26_3.mzML"
# Outcome being written to: "weighteddew_params_50_2.mzML"
# Outcome being written to: "weighteddew_params_100_1.mzML"
# Outcome being written to: "weighteddew_params_85_4.mzML"
# Outcome being written to: "weighteddew_params_90_3.mzML"
# Outcome being written to: "weighteddew_params_5_3.mzML"
# Outcome being written to: "weighteddew_params_74_2.mzML"
# Outcome being written to: "weighteddew_params_107_4.mzML"
# Outcome being written to: "weighteddew_params_37_3.mzML"
# Outcome being written to: "weighteddew_params_35_3.mzML"
# Outcome being written to: "weighteddew_params_113_2.mzML"
# Outcome being written to: "weighteddew_params_66_3.mzML"
# Outcome being written to: "weighteddew_params_22_2.mzML"
# Outcome being written to: "weighteddew_params_98_2.mzML"
# Outcome being written to: "weighteddew_params_72_3.mzML"
# Outcome being written to: "weighteddew_params_7_3.mzML"
# Outcome being written to: "weighteddew_params_63_2.mzML"
# Outcome being written to: "weighteddew_params_116_3.mzML"
# Outcome being written to: "smartroi_params_72_4.mzML"
# Outcome being written to: "weighteddew_params_13_3.mzML"
# Outcome being written to: "weighteddew_params_42_3.mzML"
# Outcome being written to: "weighteddew_params_92_3.mzML"
# Outcome being written to: "weighteddew_params_11_3.mzML"
# Outcome being written to: "weighteddew_params_96_4.mzML"
# Outcome being written to: "weighteddew_params_40_3.mzML"
# Outcome being written to: "smartroi_params_74_5.mzML"
# Outcome being written to: "weighteddew_params_87_4.mzML"
# Outcome being written to: "weighteddew_params_46_3.mzML"
# Outcome being written to: "weighteddew_params_68_3.mzML"
# Outcome being written to: "weighteddew_params_0_4.mzML"
# Outcome being written to: "weighteddew_params_105_4.mzML"
# Outcome being written to: "smartroi_params_76_5.mzML"
# Outcome being written to: "weighteddew_params_48_3.mzML"
# Outcome being written to: "weighteddew_params_111_5.mzML"
# Outcome being written to: "weighteddew_params_16_3.mzML"
# Outcome being written to: "weighteddew_params_94_3.mzML"
# Outcome being written to: "weighteddew_params_57_4.mzML"
# Outcome being written to: "weighteddew_params_61_4.mzML"
# Outcome being written to: "weighteddew_params_81_5.mzML"
# Outcome being written to: "weighteddew_params_31_4.mzML"
# Outcome being written to: "weighteddew_params_76_5.mzML"
# Outcome being written to: "weighteddew_params_55_4.mzML"
# Outcome being written to: "weighteddew_params_90_4.mzML"
# Outcome being written to: "weighteddew_params_100_2.mzML"
# Outcome being written to: "weighteddew_params_18_3.mzML"
# Outcome being written to: "weighteddew_params_70_3.mzML"
# Outcome being written to: "weighteddew_params_85_5.mzML"
# Outcome being written to: "weighteddew_params_50_3.mzML"
# Outcome being written to: "weighteddew_params_26_4.mzML"
# Outcome being written to: "weighteddew_params_107_5.mzML"
# Outcome being written to: "weighteddew_params_44_3.mzML"
# Outcome being written to: "weighteddew_params_20_2.mzML"
# Outcome being written to: "weighteddew_params_113_3.mzML"
# Outcome being written to: "weighteddew_params_66_4.mzML"
# Outcome being written to: "smartroi_params_78_5.mzML"
# Outcome being written to: "weighteddew_params_37_4.mzML"
# Outcome being written to: "weighteddew_params_72_4.mzML"
# Outcome being written to: "weighteddew_params_5_4.mzML"
# Outcome being written to: "weighteddew_params_35_4.mzML"
# Outcome being written to: "weighteddew_params_74_3.mzML"
# Outcome being written to: "weighteddew_params_116_4.mzML"
# Outcome being written to: "weighteddew_params_24_3.mzML"
# Outcome being written to: "weighteddew_params_98_3.mzML"
# Outcome being written to: "weighteddew_params_92_4.mzML"
# Outcome being written to: "weighteddew_params_96_5.mzML"
# Outcome being written to: "weighteddew_params_63_3.mzML"
# Outcome being written to: "weighteddew_params_7_4.mzML"
# Outcome being written to: "weighteddew_params_42_4.mzML"
# Outcome being written to: "weighteddew_params_22_3.mzML"
# Outcome being written to: "weighteddew_params_87_5.mzML"
# Outcome being written to: "weighteddew_params_40_4.mzML"
# Outcome being written to: "weighteddew_params_105_5.mzML"
# Outcome being written to: "weighteddew_params_46_4.mzML"
# Outcome being written to: "weighteddew_params_13_4.mzML"
# Outcome being written to: "weighteddew_params_68_4.mzML"
# Outcome being written to: "weighteddew_params_11_4.mzML"
# Outcome being written to: "weighteddew_params_117_0.mzML"
# Outcome being written to: "weighteddew_params_100_3.mzML"
# Outcome being written to: "smartroi_params_72_5.mzML"
# Outcome being written to: "weighteddew_params_0_5.mzML"
# Outcome being written to: "weighteddew_params_48_4.mzML"
# Outcome being written to: "weighteddew_params_94_4.mzML"
# Outcome being written to: "weighteddew_params_57_5.mzML"
# Outcome being written to: "weighteddew_params_121_0.mzML"
# Outcome being written to: "weighteddew_params_119_0.mzML"
# Outcome being written to: "weighteddew_params_61_5.mzML"
# Outcome being written to: "weighteddew_params_123_0.mzML"
# Outcome being written to: "weighteddew_params_16_4.mzML"
# Outcome being written to: "weighteddew_params_90_5.mzML"
# Outcome being written to: "weighteddew_params_31_5.mzML"
# Outcome being written to: "weighteddew_params_55_5.mzML"
# Outcome being written to: "weighteddew_params_70_4.mzML"
# Outcome being written to: "weighteddew_params_50_4.mzML"
# Outcome being written to: "weighteddew_params_18_4.mzML"
# Outcome being written to: "weighteddew_params_26_5.mzML"
# Outcome being written to: "weighteddew_params_113_4.mzML"
# Outcome being written to: "weighteddew_params_116_5.mzML"
# Outcome being written to: "weighteddew_params_44_4.mzML"
# Outcome being written to: "weighteddew_params_66_5.mzML"
# Outcome being written to: "weighteddew_params_72_5.mzML"
# Outcome being written to: "weighteddew_params_117_1.mzML"
# Outcome being written to: "weighteddew_params_37_5.mzML"
# Outcome being written to: "weighteddew_params_5_5.mzML"
# Outcome being written to: "weighteddew_params_74_4.mzML"
# Outcome being written to: "weighteddew_params_35_5.mzML"
# Outcome being written to: "weighteddew_params_24_4.mzML"
# Outcome being written to: "weighteddew_params_98_4.mzML"
# Outcome being written to: "weighteddew_params_121_1.mzML"
# Outcome being written to: "weighteddew_params_20_3.mzML"
# Outcome being written to: "weighteddew_params_92_5.mzML"
# Outcome being written to: "weighteddew_params_100_4.mzML"
# Outcome being written to: "weighteddew_params_63_4.mzML"
# Outcome being written to: "weighteddew_params_40_5.mzML"
# Outcome being written to: "weighteddew_params_42_5.mzML"
# Outcome being written to: "weighteddew_params_7_5.mzML"
# Outcome being written to: "weighteddew_params_22_4.mzML"
# Outcome being written to: "weighteddew_params_46_5.mzML"
# Outcome being written to: "weighteddew_params_119_1.mzML"
# Outcome being written to: "weighteddew_params_13_5.mzML"
# Outcome being written to: "weighteddew_params_68_5.mzML"
# Outcome being written to: "weighteddew_params_11_5.mzML"
# Outcome being written to: "weighteddew_params_123_1.mzML"
# Outcome being written to: "weighteddew_params_94_5.mzML"
# Outcome being written to: "weighteddew_params_48_5.mzML"
# Outcome being written to: "weighteddew_params_70_5.mzML"
# Outcome being written to: "weighteddew_params_50_5.mzML"
# Outcome being written to: "weighteddew_params_16_5.mzML"
# Outcome being written to: "weighteddew_params_117_2.mzML"
# Outcome being written to: "weighteddew_params_121_2.mzML"
# Outcome being written to: "weighteddew_params_18_5.mzML"
# Outcome being written to: "weighteddew_params_113_5.mzML"
# Outcome being written to: "weighteddew_params_100_5.mzML"
# Outcome being written to: "weighteddew_params_44_5.mzML"
# Outcome being written to: "weighteddew_params_119_2.mzML"
# Outcome being written to: "weighteddew_params_74_5.mzML"
# Outcome being written to: "weighteddew_params_98_5.mzML"
# Outcome being written to: "weighteddew_params_123_2.mzML"
# Outcome being written to: "weighteddew_params_24_5.mzML"
# Outcome being written to: "weighteddew_params_20_4.mzML"
# Outcome being written to: "weighteddew_params_63_5.mzML"
# Outcome being written to: "weighteddew_params_117_3.mzML"
# Outcome being written to: "weighteddew_params_121_3.mzML"
# Outcome being written to: "weighteddew_params_22_5.mzML"
# Outcome being written to: "weighteddew_params_119_3.mzML"
# Outcome being written to: "weighteddew_params_123_3.mzML"
# Outcome being written to: "weighteddew_params_121_4.mzML"
# Outcome being written to: "weighteddew_params_117_4.mzML"
# Outcome being written to: "weighteddew_params_20_5.mzML"
# Outcome being written to: "weighteddew_params_119_4.mzML"
# Outcome being written to: "weighteddew_params_121_5.mzML"
# Outcome being written to: "weighteddew_params_123_4.mzML"
# Outcome being written to: "weighteddew_params_117_5.mzML"
# Outcome being written to: "weighteddew_params_122_0.mzML"
# Outcome being written to: "weighteddew_params_119_5.mzML"
# Outcome being written to: "weighteddew_params_123_5.mzML"
# Outcome being written to: "weighteddew_params_118_0.mzML"
# Outcome being written to: "weighteddew_params_122_1.mzML"
# Outcome being written to: "weighteddew_params_118_1.mzML"
# Outcome being written to: "weighteddew_params_120_0.mzML"
# Outcome being written to: "weighteddew_params_124_0.mzML"
# Outcome being written to: "weighteddew_params_122_2.mzML"
# Outcome being written to: "weighteddew_params_120_1.mzML"
# Outcome being written to: "weighteddew_params_118_2.mzML"
# Outcome being written to: "weighteddew_params_124_1.mzML"
# Outcome being written to: "weighteddew_params_122_3.mzML"
# Outcome being written to: "weighteddew_params_120_2.mzML"
# Outcome being written to: "weighteddew_params_118_3.mzML"
# Outcome being written to: "weighteddew_params_122_4.mzML"
# Outcome being written to: "weighteddew_params_124_2.mzML"
# Outcome being written to: "weighteddew_params_120_3.mzML"
# Outcome being written to: "weighteddew_params_118_4.mzML"
# Outcome being written to: "weighteddew_params_120_4.mzML"
# Outcome being written to: "weighteddew_params_122_5.mzML"
# Outcome being written to: "weighteddew_params_124_3.mzML"
# Outcome being written to: "weighteddew_params_120_5.mzML"
# Outcome being written to: "weighteddew_params_118_5.mzML"
# Outcome being written to: "weighteddew_params_124_4.mzML"
# Outcome being written to: "weighteddew_params_124_5.mzML"
