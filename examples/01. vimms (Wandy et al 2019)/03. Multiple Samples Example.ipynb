# %% [markdown]
# # 3. Generating Multiple Samples using MS1 Controller

# %% [markdown]
# In this notebook, we demonstrate how ViMMS can be used to generate multiple samples (sets of chemicals) that are biological and technical replicates. The MS1 controller is then used to produce mass spectral data in form of .mzML files for the multiple samples.

# %%
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from collections import defaultdict
import os
from pathlib import Path

# %%
import sys
sys.path.append('../..')

# %%
from vimms.Chemicals import ChemicalCreator, MultiSampleCreator
from vimms.MassSpec import IndependentMassSpectrometer
from vimms.Controller import SimpleMs1Controller
from vimms.Environment import Environment
from vimms.Common import *

# %% [markdown]
# Load previously trained KDEs in `PeakSampler` and the list of extracted metabolites, created in **01. Download Data.ipynb**.

# %%
base_dir = os.path.abspath('example_data')
ps = load_obj(Path(base_dir, 'peak_sampler_mz_rt_int_19_beers_fullscan.p'))
hmdb = load_obj(Path(base_dir, 'hmdb_compounds.p'))

# %% [markdown]
# Set ViMMS logging level

# %%
set_log_level_warning()
# set_log_level_info()
# set_log_level_debug()

# %% [markdown]
# ## Create Initial Chemical

# %% [markdown]
# Define an output folder containing our results

# %%
out_dir = Path(base_dir, 'results', 'MS1_multiple')

# %% [markdown]
# Here we generate multiple chemical objects that will be used across samples. The chemical objects are generated by sampling from metabolites in the HMDB database.

# %%
# the list of ROI sources created in the previous notebook '01. Download Data.ipynb'
ROI_Sources = [str(Path(base_dir,'DsDA', 'DsDA_Beer', 'beer_t10_simulator_files'))]

# minimum MS1 intensity of chemicals
min_ms1_intensity = 1.75E5

# m/z and RT range of chemicals
rt_range = [(400, 800)]
mz_range = [(100, 400)]

# the number of chemicals in the sample
n_chems = 1000

# maximum MS level (we do not generate fragmentation peaks when this value is 1)
ms_level = 1

# for this experiment, we restrict the sampled chromatograms to be within 20 - 40s in length
# so they are not too big and too small
roi_rt_range = [20, 40]

# %%
chems = ChemicalCreator(ps, ROI_Sources, hmdb)
dataset = chems.sample(mz_range, rt_range, min_ms1_intensity, n_chems, ms_level, roi_rt_range=roi_rt_range)
save_obj(dataset, Path(out_dir, 'BaseDataset', 'dataset.p'))

# %%
for chem in dataset[0:10]:
    print(chem)
# Out:
# KnownChemical - 'C5H12N2O' rt=707.41 max_intensity=1567498579.15
# KnownChemical - 'C9H18O2' rt=732.15 max_intensity=1188980.50
# KnownChemical - 'C15H12O10S' rt=421.13 max_intensity=568706.93
# KnownChemical - 'C19H26' rt=556.11 max_intensity=791810.73
# KnownChemical - 'C19H35NO' rt=412.62 max_intensity=3530450.33
# KnownChemical - 'C2H4Cl2O2' rt=692.57 max_intensity=1991866.40
# KnownChemical - 'C2H7NO2S' rt=514.64 max_intensity=802075.41
# KnownChemical - 'C10H20O2S' rt=541.53 max_intensity=8164111.00
# KnownChemical - 'C7H5NS' rt=734.46 max_intensity=53629606.41
# KnownChemical - 'C17H34O2' rt=392.41 max_intensity=14368080.46

# %% [markdown]
# ## Create Multiple Samples

# %% [markdown]
# The next section allows us to define classes of biological replicates, each having multiple technical replicates.
#
# Below we create two biological classes ('class0', 'class1'), each having 10 technical replicates with some noise on the chemical's intensity.

# %%
n_samples = [10, 10] # number of files per class
classes = ["class%d" % i for i in range(len(n_samples))] # creates default list of classes
intensity_noise_sd = [1000] # noise on max intensity

# %%
classes
# Out:
# ['class0', 'class1']

# %% [markdown]
# Add intensity changes between different classes

# %%
change_probabilities = [0 for i in range(len(n_samples))] # probability of intensity changes between different classes
change_differences_means = [0 for i in range(len(n_samples))] # mean of those intensity changes
change_differences_sds = [0 for i in range(len(n_samples))] # SD of those intensity changes

# %% [markdown]
# Add experimental variables (examples in comments)

# %%
experimental_classes = None # [["male","female"],["Positive","Negative","Unknown"]]
experimental_probabilitities = None # [[0.5,0.5],[0.33,0.33,0.34]]
experimental_sds = None # [[250],[250]]

# %% [markdown]
# Dropout chemicals in different classes

# %%
# drop-out chemicals by their probabilities
dropout_probability = 0.2
dropout_probabilities = [dropout_probability for i in range(len(n_samples))]
dropout_numbers = None # drop-out chemicals by an absolute number

# dropout_probabilities = None
# dropout_numbers = 2 # number of chemicals dropped out in each class

# %% [markdown]
# Generate multiple samples

# %%
save_location = os.path.join(out_dir, 'ChemicalFiles')

# %%
multiple_samples = MultiSampleCreator(dataset, n_samples, classes, intensity_noise_sd, 
                                      change_probabilities, change_differences_means, change_differences_sds, dropout_probabilities, dropout_numbers,
                                     experimental_classes, experimental_probabilitities, experimental_sds, save_location=save_location)

# %%
total_samples = np.sum(multiple_samples.n_samples)
total_samples
# Out:
# 20

# %% [markdown]
# We can also print the chemicals that are missing (removed by drop-out) in each class.

# %%
save_obj(multiple_samples.missing_chemicals, Path(out_dir, 'MissingChemicals', 'missing_chemicals.p'))
multiple_samples.missing_chemicals
# Out:
# [[KnownChemical - 'C19H35NO' rt=412.62 max_intensity=3530450.33,
#   KnownChemical - 'C8H12NO6P' rt=572.12 max_intensity=2461859.41,
#   KnownChemical - 'C5H6Cl6N2O3' rt=488.60 max_intensity=372050.12,
#   KnownChemical - 'C10H19NO3' rt=530.82 max_intensity=3381347.00,
#   KnownChemical - 'C6H13NO8S' rt=407.75 max_intensity=20679709.08,
#   KnownChemical - 'C8H9NO6S' rt=634.37 max_intensity=237635.70,
#   KnownChemical - 'C17H15O7' rt=523.17 max_intensity=669669.21,
#   KnownChemical - 'C17H22' rt=392.18 max_intensity=1734070.17,
#   KnownChemical - 'C8H13NO5' rt=558.94 max_intensity=188779.35,
#   KnownChemical - 'C20H40' rt=580.68 max_intensity=877148.50,
#   KnownChemical - 'C6H15NO' rt=774.94 max_intensity=1230183.64,
#   KnownChemical - 'C14H10' rt=426.45 max_intensity=1035516.57,
#   KnownChemical - 'C23H30N2O4' rt=680.06 max_intensity=1035314.70,
#   KnownChemical - 'C15H12O9' rt=655.88 max_intensity=2478870.53,
#   KnownChemical - 'C3H3Br2IO' rt=398.65 max_intensity=949078.79,
#   KnownChemical - 'C14H24' rt=628.10 max_intensity=4551096.22,
#   KnownChemical - 'C8H8O5S' rt=570.84 max_intensity=207769.17,
#   KnownChemical - 'C10H20O2' rt=715.28 max_intensity=1198783.05,
#   KnownChemical - 'C4F8' rt=698.28 max_intensity=5555870.22,
#   KnownChemical - 'C10H16O' rt=505.75 max_intensity=13408711.30,
#   KnownChemical - 'C20H42' rt=596.50 max_intensity=192800.71,
#   KnownChemical - 'C5H9NO3' rt=582.77 max_intensity=3861649.91,
#   KnownChemical - 'C8H11NO5S' rt=680.32 max_intensity=1179620.74,
#   KnownChemical - 'C22H37NO2' rt=541.80 max_intensity=5670259.34,
#   KnownChemical - 'C11H16N2O2' rt=535.37 max_intensity=326804.43,
#   KnownChemical - 'HNO5S' rt=418.81 max_intensity=193173.53,
#   KnownChemical - 'C9H7NO3' rt=691.02 max_intensity=3544274.78,
#   KnownChemical - 'C6H8O9S' rt=536.61 max_intensity=1534871.44,
#   KnownChemical - 'C8H8N2O2S2' rt=429.16 max_intensity=547023.20,
#   KnownChemical - 'C13H9NO3' rt=560.31 max_intensity=218633.63,
#   KnownChemical - 'C12H13NO5' rt=566.02 max_intensity=284555.51,
#   KnownChemical - 'C4H8N2S4' rt=559.28 max_intensity=637946.31,
#   KnownChemical - 'C10H14N5O8P' rt=735.46 max_intensity=23093666.29,
#   KnownChemical - 'C17H30O' rt=399.58 max_intensity=1435304.66,
#   KnownChemical - 'C21H36O2' rt=731.28 max_intensity=299820.81,
#   KnownChemical - 'C6H11N3' rt=480.74 max_intensity=1323800.79,
#   KnownChemical - 'C2ClF5' rt=444.56 max_intensity=483894.70,
#   KnownChemical - 'C15H12O5S' rt=437.83 max_intensity=241194.38,
#   KnownChemical - 'C13H20O' rt=483.84 max_intensity=2717722.22,
#   KnownChemical - 'C3H7NO2S' rt=555.88 max_intensity=2786585.69,
#   KnownChemical - 'C6H6O4S' rt=459.83 max_intensity=1616662.08,
#   KnownChemical - 'C14H7ClF3NO5' rt=429.51 max_intensity=256496.66,
#   KnownChemical - 'C5H5NO2' rt=537.12 max_intensity=205515.02,
#   KnownChemical - 'C10H7N3S' rt=414.40 max_intensity=1386572.17,
#   KnownChemical - 'C21H29NO' rt=656.66 max_intensity=343514.85,
#   KnownChemical - 'C14H28O2' rt=624.22 max_intensity=2053802.29,
#   KnownChemical - 'C10H14NO5PS' rt=498.06 max_intensity=1578023.98,
#   KnownChemical - 'C9H21N3O' rt=583.93 max_intensity=406654.26,
#   KnownChemical - 'C3H9NO3S2' rt=409.48 max_intensity=1426118.95,
#   KnownChemical - 'C12H14N4O3S' rt=577.91 max_intensity=306147.63,
#   KnownChemical - 'C16H20NO3' rt=556.22 max_intensity=689402.23,
#   KnownChemical - 'C14H14N2OS2' rt=553.40 max_intensity=224272.68,
#   KnownChemical - 'C17H22O5' rt=451.17 max_intensity=389860.07,
#   KnownChemical - 'C4H5NO4' rt=752.87 max_intensity=997774.90,
#   KnownChemical - 'C6H5NO3' rt=530.90 max_intensity=1976145.82,
#   KnownChemical - 'C6H11NOS2' rt=756.89 max_intensity=561551.68,
#   KnownChemical - 'C7H11N' rt=569.14 max_intensity=386875.18,
#   KnownChemical - 'C16H33NO' rt=509.41 max_intensity=144054296.90,
#   KnownChemical - 'C9H9N5O5' rt=428.88 max_intensity=430439.91,
#   KnownChemical - 'C9H8ClNO4' rt=599.93 max_intensity=8661265.39,
#   KnownChemical - 'H5IO6' rt=550.06 max_intensity=2471596.64,
#   KnownChemical - 'C3H11NO7P2' rt=782.93 max_intensity=2538944.49,
#   KnownChemical - 'C22H38O2' rt=462.57 max_intensity=412199.88,
#   KnownChemical - 'C6H9NOS' rt=762.59 max_intensity=4265654.79,
#   KnownChemical - 'C18H39N3O' rt=632.70 max_intensity=16203876.77,
#   KnownChemical - 'C8H3NO2' rt=747.74 max_intensity=508623.65,
#   KnownChemical - 'C4H3FN2O2' rt=747.17 max_intensity=2031409.80,
#   KnownChemical - 'C12H11NO6' rt=696.85 max_intensity=858445.55,
#   KnownChemical - 'C18H39NO2' rt=687.43 max_intensity=290056.32,
#   KnownChemical - 'C17H35NO' rt=386.63 max_intensity=540222.11,
#   KnownChemical - 'C8H14O2' rt=424.85 max_intensity=1014470.04,
#   KnownChemical - 'C20H30' rt=737.50 max_intensity=1409585.46,
#   KnownChemical - 'C8H14' rt=599.84 max_intensity=592480.96,
#   KnownChemical - 'C6H14O10P2' rt=744.43 max_intensity=1432255.61,
#   KnownChemical - 'C13H10ClN3O4S2' rt=413.46 max_intensity=793094.43,
#   KnownChemical - 'C6H5BrO' rt=449.70 max_intensity=83302693.18,
#   KnownChemical - 'C10H13N3O' rt=791.58 max_intensity=315051.15,
#   KnownChemical - 'C6H4Cl2' rt=598.41 max_intensity=336464.37,
#   KnownChemical - 'C14H20O' rt=625.74 max_intensity=1225202.32,
#   KnownChemical - 'C20H39NO' rt=729.49 max_intensity=418336.05,
#   KnownChemical - 'C8H6O7S' rt=391.00 max_intensity=330007.34,
#   KnownChemical - 'C6H7NO4S' rt=545.70 max_intensity=1608972.22,
#   KnownChemical - 'C7H6O3' rt=419.69 max_intensity=282284.00,
#   KnownChemical - 'C6H14O3' rt=436.56 max_intensity=433614.62,
#   KnownChemical - 'C13H17NO3' rt=566.79 max_intensity=736377.97,
#   KnownChemical - 'C9H6N2S' rt=443.96 max_intensity=990629.43,
#   KnownChemical - 'C12H12N2O3S' rt=604.69 max_intensity=3462549.07,
#   KnownChemical - 'C16H10O7' rt=774.56 max_intensity=5195623.12,
#   KnownChemical - 'C13H19ClN2O2' rt=414.73 max_intensity=823021.83,
#   KnownChemical - 'C10H20O' rt=417.68 max_intensity=951836.87,
#   KnownChemical - 'C8H12N2O3S' rt=414.02 max_intensity=1670813.89,
#   KnownChemical - 'C14H18O6' rt=639.07 max_intensity=528728.41,
#   KnownChemical - 'C9H10N4O2S2' rt=583.76 max_intensity=1048104.01,
#   KnownChemical - 'C12H22O8' rt=705.99 max_intensity=358972.99,
#   KnownChemical - 'C4H10N3O5P' rt=425.99 max_intensity=312409.23,
#   KnownChemical - 'C8H17N' rt=460.78 max_intensity=2086473.76,
#   KnownChemical - 'CH5NO2S6' rt=464.09 max_intensity=204092.63,
#   KnownChemical - 'C6H6Cl6' rt=465.68 max_intensity=239673.02,
#   KnownChemical - 'C10H12N4O4S' rt=786.38 max_intensity=245962.17,
#   KnownChemical - 'C4H6O3S2' rt=497.37 max_intensity=184968.26,
#   KnownChemical - 'C15H23N' rt=455.92 max_intensity=23954541.64,
#   KnownChemical - 'C3H6O3S2' rt=605.22 max_intensity=222110.10,
#   KnownChemical - 'C4H7NS2' rt=718.32 max_intensity=1692881.07,
#   KnownChemical - 'C8H6S4' rt=437.68 max_intensity=251855.31,
#   KnownChemical - 'C12H13N2O' rt=459.46 max_intensity=8859338.53,
#   KnownChemical - 'C12H28N4O' rt=592.05 max_intensity=1541332.22,
#   KnownChemical - 'C3H7NO5S2' rt=416.66 max_intensity=533522.69,
#   KnownChemical - 'C10H14N5O6P' rt=579.69 max_intensity=624580.48,
#   KnownChemical - 'C11H17N' rt=452.68 max_intensity=12987129.34,
#   KnownChemical - 'C13H26O3' rt=572.80 max_intensity=267068.94,
#   KnownChemical - 'C9H11FN2O5' rt=720.03 max_intensity=20193630.41,
#   KnownChemical - 'C5H5N3O2' rt=404.55 max_intensity=937756.16,
#   KnownChemical - 'C6HCl3O4' rt=522.86 max_intensity=3703472.02,
#   KnownChemical - 'C15H10Cl2N2O2' rt=731.37 max_intensity=1677497.01,
#   KnownChemical - 'C16H34' rt=429.05 max_intensity=201975.15,
#   KnownChemical - 'C9H19N' rt=424.03 max_intensity=569849.80,
#   KnownChemical - 'C2HCl3' rt=420.52 max_intensity=276557.96,
#   KnownChemical - 'C14H8N2O6' rt=499.07 max_intensity=703993.40,
#   KnownChemical - 'C10H7NO' rt=401.05 max_intensity=192503.98,
#   KnownChemical - 'C16H30O' rt=567.09 max_intensity=444876.63,
#   KnownChemical - 'C10H12' rt=409.41 max_intensity=20678407.98,
#   KnownChemical - 'C16H23NO' rt=420.60 max_intensity=456766061.32,
#   KnownChemical - 'C12H13N5' rt=402.45 max_intensity=679401.52,
#   KnownChemical - 'C8H7NS' rt=429.61 max_intensity=205408.84,
#   KnownChemical - 'C7H15Cl2N2O3P' rt=395.11 max_intensity=2457700.77,
#   KnownChemical - 'C17H33NO5' rt=459.05 max_intensity=1174168.98,
#   KnownChemical - 'C12H10N2O5S' rt=675.39 max_intensity=261929.65,
#   KnownChemical - 'C12H21N5O3' rt=417.05 max_intensity=1120555.18,
#   KnownChemical - 'C5H9N3O3' rt=747.01 max_intensity=1028029.53,
#   KnownChemical - 'C9H10O4S' rt=584.42 max_intensity=9217764.86,
#   KnownChemical - 'C8H14O' rt=689.99 max_intensity=208933.02,
#   KnownChemical - 'C22H44' rt=589.39 max_intensity=168659230.34,
#   KnownChemical - 'C17H34O' rt=609.71 max_intensity=517936.29,
#   KnownChemical - 'C6H13AsO3' rt=556.62 max_intensity=4633915.94,
#   KnownChemical - 'C15H11N3O3' rt=750.04 max_intensity=432097.96,
#   KnownChemical - 'C5H11NO3S' rt=617.92 max_intensity=184107.69,
#   KnownChemical - 'C5H6OS2' rt=465.43 max_intensity=340276.02,
#   KnownChemical - 'C2H4S5' rt=731.57 max_intensity=225214.92,
#   KnownChemical - 'C20H21NO3' rt=645.54 max_intensity=702566.30,
#   KnownChemical - 'C19H32O' rt=434.03 max_intensity=53651456.22,
#   KnownChemical - 'C2H3Cl3O' rt=396.76 max_intensity=524066.20,
#   KnownChemical - 'C14H14INO2' rt=737.39 max_intensity=319167.93,
#   KnownChemical - 'C11H18O2' rt=487.77 max_intensity=215596.21,
#   KnownChemical - 'C7H11NO6S' rt=416.38 max_intensity=719997.85,
#   KnownChemical - 'C21H36NO' rt=445.30 max_intensity=203689.54,
#   KnownChemical - 'C13H17N' rt=485.19 max_intensity=211290.06,
#   KnownChemical - 'C5H5NOS' rt=719.46 max_intensity=3355603.38,
#   KnownChemical - 'C6H9N3O3' rt=466.78 max_intensity=8737118.19,
#   KnownChemical - 'C22H46O' rt=530.38 max_intensity=941119.01,
#   KnownChemical - 'C8H15NO3' rt=658.68 max_intensity=58897100.57,
#   KnownChemical - 'C14H10N2O9S' rt=472.52 max_intensity=275730.20,
#   KnownChemical - 'C8H11Cl2N3O2' rt=468.39 max_intensity=470349.16,
#   KnownChemical - 'C6H6O8S2' rt=503.16 max_intensity=26513397.15,
#   KnownChemical - 'C3H3ClO2' rt=569.93 max_intensity=386774.38,
#   KnownChemical - 'C8H18' rt=426.87 max_intensity=302018.39,
#   KnownChemical - 'C6H13O7PS' rt=615.67 max_intensity=1020384.79,
#   KnownChemical - 'C9H8O8S' rt=719.25 max_intensity=26555066.73,
#   KnownChemical - 'C4H5N3O2' rt=540.45 max_intensity=1065401.10,
#   KnownChemical - 'C6H12N3PS' rt=428.64 max_intensity=214849.94,
#   KnownChemical - 'C19H40O3' rt=429.22 max_intensity=246981.74,
#   KnownChemical - 'C9H12N3O7P' rt=589.44 max_intensity=92387331.26,
#   KnownChemical - 'C10H17N' rt=429.15 max_intensity=336795.80,
#   KnownChemical - 'C6H11N3O3' rt=576.90 max_intensity=274462.00,
#   KnownChemical - 'C3H12NO9P3' rt=771.80 max_intensity=822467.32,
#   KnownChemical - 'C15H30O2' rt=625.71 max_intensity=449261.78,
#   KnownChemical - 'C10H18' rt=612.80 max_intensity=10514961.37,
#   KnownChemical - 'C14H12ClNO3' rt=457.70 max_intensity=1392338.08,
#   KnownChemical - 'C14H19NO' rt=425.11 max_intensity=528985.74,
#   KnownChemical - 'C3H6S3' rt=397.17 max_intensity=369193.15,
#   KnownChemical - 'C10H7NO2' rt=782.20 max_intensity=376569.17,
#   KnownChemical - 'C8H7NO4' rt=550.78 max_intensity=309590.79,
#   KnownChemical - 'C18H28N2O4' rt=406.41 max_intensity=694938.10,
#   KnownChemical - 'C12H22O' rt=609.07 max_intensity=15231294.71,
#   KnownChemical - 'C10H16N2O5' rt=558.40 max_intensity=734735.41,
#   KnownChemical - 'C12H25N3O3' rt=411.75 max_intensity=325044.99,
#   KnownChemical - 'C15H23N5O4' rt=781.89 max_intensity=887787.01,
#   KnownChemical - 'C20H10O6' rt=437.05 max_intensity=1831189.88,
#   KnownChemical - 'C19H35NO2' rt=764.06 max_intensity=2055562.05,
#   KnownChemical - 'C9H15NO2' rt=726.47 max_intensity=1171998.87,
#   KnownChemical - 'C21H34O' rt=708.93 max_intensity=1293949.92,
#   KnownChemical - 'C14H25NO' rt=535.52 max_intensity=6131642.12,
#   KnownChemical - 'C22H37NO3' rt=781.57 max_intensity=6710617.99,
#   KnownChemical - 'C5H4BrN' rt=772.30 max_intensity=9748429.21,
#   KnownChemical - 'C11H11F3N2O4' rt=657.33 max_intensity=482904885.20,
#   KnownChemical - 'C6H15O13P3' rt=736.42 max_intensity=348021.65,
#   KnownChemical - 'C4H7N3O' rt=597.43 max_intensity=224000.54,
#   KnownChemical - 'C7H8O4' rt=397.54 max_intensity=329645.20,
#   KnownChemical - 'C8H11NO' rt=460.81 max_intensity=474052.23,
#   KnownChemical - 'C7H10OS2' rt=677.66 max_intensity=602710.69,
#   KnownChemical - 'C10H10S3' rt=734.66 max_intensity=329941.39,
#   KnownChemical - 'CHBr2Cl' rt=646.98 max_intensity=2215196.07,
#   KnownChemical - 'C16H25NO4' rt=710.93 max_intensity=3148141.38,
#   KnownChemical - 'C11H24O' rt=421.34 max_intensity=585596.74,
#   KnownChemical - 'C15H18O9' rt=505.80 max_intensity=598524.81,
#   KnownChemical - 'C9H7NO' rt=570.00 max_intensity=379994.18,
#   KnownChemical - 'C13H16O8' rt=605.31 max_intensity=674419.74,
#   KnownChemical - 'C20H39NO5' rt=551.70 max_intensity=12613431.51,
#   KnownChemical - 'C7H10N2O' rt=409.62 max_intensity=196120.94,
#   KnownChemical - 'C19H39NO' rt=420.56 max_intensity=1340235.19,
#   KnownChemical - 'C8H23N5' rt=571.79 max_intensity=12501656.14,
#   KnownChemical - 'C11H10BrN5' rt=766.16 max_intensity=209454.32],
#  [KnownChemical - 'C5H12N2O' rt=707.41 max_intensity=1567498579.15,
#   KnownChemical - 'C15H12O10S' rt=421.13 max_intensity=568706.93,
#   KnownChemical - 'C19H26' rt=556.11 max_intensity=791810.73,
#   KnownChemical - 'C7H5NS' rt=734.46 max_intensity=53629606.41,
#   KnownChemical - 'C17H34O2' rt=392.41 max_intensity=14368080.46,
#   KnownChemical - 'C12H15NO4' rt=661.04 max_intensity=1255512.54,
#   KnownChemical - 'C10H7N3O4S' rt=584.88 max_intensity=528603.53,
#   KnownChemical - 'C15H10O6' rt=501.92 max_intensity=2037652.64,
#   KnownChemical - 'C6H13NO8S' rt=407.75 max_intensity=20679709.08,
#   KnownChemical - 'C9H16O' rt=598.85 max_intensity=296945.49,
#   KnownChemical - 'C9H19NO4' rt=447.21 max_intensity=176171.07,
#   KnownChemical - 'C7H11NO3' rt=522.89 max_intensity=748252.82,
#   KnownChemical - 'C15H32' rt=524.81 max_intensity=5189476.48,
#   KnownChemical - 'CBr2Cl2' rt=563.09 max_intensity=1085606.59,
#   KnownChemical - 'C6H9NO2' rt=428.54 max_intensity=850652.60,
#   KnownChemical - 'C10H11NO3' rt=448.28 max_intensity=1977794.39,
#   KnownChemical - 'C4H4O6' rt=403.31 max_intensity=203114.66,
#   KnownChemical - 'C7H11N3O' rt=425.14 max_intensity=683603.62,
#   KnownChemical - 'C3H3Br2IO' rt=398.65 max_intensity=949078.79,
#   KnownChemical - 'C11H19NO' rt=739.92 max_intensity=1054058.71,
#   KnownChemical - 'C5H9N3' rt=684.57 max_intensity=585607.58,
#   KnownChemical - 'C10H17NS' rt=760.25 max_intensity=1155987.15,
#   KnownChemical - 'C9H7NO5S' rt=574.94 max_intensity=228603.32,
#   KnownChemical - 'C17H22O2' rt=590.50 max_intensity=1855045.50,
#   KnownChemical - 'C5H9NO3' rt=582.77 max_intensity=3861649.91,
#   KnownChemical - 'C7H4ClNO2' rt=418.38 max_intensity=214259.50,
#   KnownChemical - 'C18H32O2' rt=587.27 max_intensity=464443.62,
#   KnownChemical - 'C12H13NO4' rt=533.19 max_intensity=31001592.30,
#   KnownChemical - 'C12H22O3' rt=611.15 max_intensity=201834.69,
#   KnownChemical - 'C9H7NO3' rt=691.02 max_intensity=3544274.78,
#   KnownChemical - 'C13H9NO2S' rt=657.45 max_intensity=959010.49,
#   KnownChemical - 'H3IO3' rt=681.87 max_intensity=414415.98,
#   KnownChemical - 'C2Cl4' rt=588.07 max_intensity=10702088.84,
#   KnownChemical - 'C11H20O' rt=627.43 max_intensity=1520685.54,
#   KnownChemical - 'C18H38O' rt=594.83 max_intensity=4402074.18,
#   KnownChemical - 'C16H20O4' rt=660.39 max_intensity=1655706.45,
#   KnownChemical - 'C2H6Fe2N4O4S2' rt=670.85 max_intensity=50258909.41,
#   KnownChemical - 'C17H36' rt=679.70 max_intensity=904352.43,
#   KnownChemical - 'C9H10O6S' rt=429.52 max_intensity=298572.25,
#   KnownChemical - 'C10H10ClN3' rt=764.79 max_intensity=238765.08,
#   KnownChemical - 'C6H6O6' rt=556.50 max_intensity=2507964.19,
#   KnownChemical - 'C15H12O5S' rt=437.83 max_intensity=241194.38,
#   KnownChemical - 'C13H20O' rt=483.84 max_intensity=2717722.22,
#   KnownChemical - 'CCl2F2' rt=540.95 max_intensity=2033052.92,
#   KnownChemical - 'C5HCl4NO2' rt=611.46 max_intensity=1750033.26,
#   KnownChemical - 'C13H26O4' rt=741.03 max_intensity=245737.92,
#   KnownChemical - 'C2H7NO3S' rt=644.59 max_intensity=427872.32,
#   KnownChemical - 'C21H32N2O' rt=407.42 max_intensity=700042.01,
#   KnownChemical - 'C9H21N3O' rt=583.93 max_intensity=406654.26,
#   KnownChemical - 'C20H18O5' rt=513.27 max_intensity=195328.13,
#   KnownChemical - 'C16H20NO3' rt=556.22 max_intensity=689402.23,
#   KnownChemical - 'C10H21N5O4' rt=540.29 max_intensity=1049296.75,
#   KnownChemical - 'C9H14N3O9P' rt=525.95 max_intensity=346735.59,
#   KnownChemical - 'C15H32N2' rt=753.44 max_intensity=6377027.10,
#   KnownChemical - 'C6HCl4NO2' rt=526.96 max_intensity=1470410.30,
#   KnownChemical - 'C9H14N3O8P' rt=427.36 max_intensity=1572227.87,
#   KnownChemical - 'C3H11NO7P2' rt=782.93 max_intensity=2538944.49,
#   KnownChemical - 'C12H18' rt=688.65 max_intensity=4136072.43,
#   KnownChemical - 'C8H17NO5' rt=412.06 max_intensity=224146.31,
#   KnownChemical - 'C20H25NO2S2' rt=536.45 max_intensity=190797.78,
#   KnownChemical - 'C8H17N3O3' rt=415.72 max_intensity=192110.25,
#   KnownChemical - 'C2H2Cl2O' rt=412.82 max_intensity=29019528.36,
#   KnownChemical - 'CHF3O3S' rt=414.14 max_intensity=2681105.37,
#   KnownChemical - 'C4H3FN2O2' rt=747.17 max_intensity=2031409.80,
#   KnownChemical - 'C18H34O' rt=389.42 max_intensity=545065.23,
#   KnownChemical - 'C9H10ClNO3' rt=415.83 max_intensity=453574.61,
#   KnownChemical - 'C12H11NO6' rt=696.85 max_intensity=858445.55,
#   KnownChemical - 'C4H7Br2Cl2O4P' rt=535.82 max_intensity=559506.47,
#   KnownChemical - 'C9H13N' rt=727.44 max_intensity=1364870.22,
#   KnownChemical - 'C18H39N' rt=724.13 max_intensity=394677.36,
#   KnownChemical - 'C8H11N3O4S' rt=650.80 max_intensity=1037055.64,
#   KnownChemical - 'C6H4Cl2' rt=598.41 max_intensity=336464.37,
#   KnownChemical - 'C3H8OS2' rt=570.94 max_intensity=527411.86,
#   KnownChemical - 'C20H39NO' rt=729.49 max_intensity=418336.05,
#   KnownChemical - 'C8H11NO4S' rt=781.83 max_intensity=5508142.66,
#   KnownChemical - 'C8H6O7S' rt=391.00 max_intensity=330007.34,
#   KnownChemical - 'C12H9N3O5S' rt=748.74 max_intensity=1092086.66,
#   KnownChemical - 'C8H7N' rt=431.63 max_intensity=386241.90,
#   KnownChemical - 'C13H8S2' rt=596.75 max_intensity=2934624.00,
#   KnownChemical - 'C9H6N2S' rt=443.96 max_intensity=990629.43,
#   KnownChemical - 'C11H19NO9S2' rt=654.57 max_intensity=2521812.63,
#   KnownChemical - 'C16H10O7' rt=774.56 max_intensity=5195623.12,
#   KnownChemical - 'C18H36' rt=622.66 max_intensity=273054.12,
#   KnownChemical - 'C10H13N3O2' rt=519.14 max_intensity=289773.06,
#   KnownChemical - 'C22H44O3' rt=536.35 max_intensity=8273400.04,
#   KnownChemical - 'C8H16O' rt=414.25 max_intensity=8622097.56,
#   KnownChemical - 'C18H16N2O' rt=571.22 max_intensity=5037322.05,
#   KnownChemical - 'C14H8N2O3' rt=773.72 max_intensity=850283.29,
#   KnownChemical - 'C5H9N3O4' rt=421.99 max_intensity=8070274.94,
#   KnownChemical - 'C7H13NO4S' rt=421.72 max_intensity=4991566.74,
#   KnownChemical - 'C8H17N' rt=460.78 max_intensity=2086473.76,
#   KnownChemical - 'C6H15N4O2' rt=424.96 max_intensity=2133803.07,
#   KnownChemical - 'C14H21NO2' rt=396.71 max_intensity=372743.15,
#   KnownChemical - 'C3H6O3S2' rt=605.22 max_intensity=222110.10,
#   KnownChemical - 'C11H18' rt=602.28 max_intensity=229119.87,
#   KnownChemical - 'C5H13N3O' rt=414.70 max_intensity=400413.41,
#   KnownChemical - 'C8H18NO2' rt=690.12 max_intensity=210204.17,
#   KnownChemical - 'CHCl3' rt=619.34 max_intensity=179465.75,
#   KnownChemical - 'C10H14' rt=740.46 max_intensity=71988427.89,
#   KnownChemical - 'C11H15N' rt=510.87 max_intensity=1427785.62,
#   KnownChemical - 'C20H29NO3' rt=404.87 max_intensity=387509.65,
#   KnownChemical - 'C9H21N2O3' rt=612.90 max_intensity=266616.09,
#   KnownChemical - 'H2O3S2' rt=761.91 max_intensity=2052311.26,
#   KnownChemical - 'C15H27NO3' rt=730.13 max_intensity=889488.91,
#   KnownChemical - 'C7H3Cl5O' rt=755.57 max_intensity=8043820.10,
#   KnownChemical - 'C19H32O2' rt=452.12 max_intensity=427985.06,
#   KnownChemical - 'C3H7NO5S2' rt=416.66 max_intensity=533522.69,
#   KnownChemical - 'C14H19NO2' rt=666.55 max_intensity=915424.99,
#   KnownChemical - 'C14H22O' rt=600.91 max_intensity=937604.45,
#   KnownChemical - 'C7H5NO2' rt=412.22 max_intensity=960009.80,
#   KnownChemical - 'C11H17N' rt=452.68 max_intensity=12987129.34,
#   KnownChemical - 'C13H26O3' rt=572.80 max_intensity=267068.94,
#   KnownChemical - 'C18H21NO3' rt=442.62 max_intensity=323347.28,
#   KnownChemical - 'C10H13N3' rt=638.97 max_intensity=200413620.91,
#   KnownChemical - 'C6Cl6' rt=413.33 max_intensity=375840.82,
#   KnownChemical - 'C14H12O5' rt=659.32 max_intensity=4811653.05,
#   KnownChemical - 'C11H13NO3' rt=789.07 max_intensity=1011046.75,
#   KnownChemical - 'C3H7NO3' rt=678.26 max_intensity=266842.75,
#   KnownChemical - 'C7H8O5S' rt=626.70 max_intensity=2271662.97,
#   KnownChemical - 'C9H9NO2' rt=547.59 max_intensity=599594.48,
#   KnownChemical - 'C6HCl3O4' rt=522.86 max_intensity=3703472.02,
#   KnownChemical - 'C20H34O3' rt=476.29 max_intensity=594805.59,
#   KnownChemical - 'C16H34' rt=429.05 max_intensity=201975.15,
#   KnownChemical - 'C2HCl3' rt=420.52 max_intensity=276557.96,
#   KnownChemical - 'C5H3N4O3' rt=675.93 max_intensity=4023949.85,
#   KnownChemical - 'C7H15N3O2' rt=629.10 max_intensity=909996.90,
#   KnownChemical - 'C3H7NO5S' rt=537.57 max_intensity=1662385.86,
#   KnownChemical - 'C12H16' rt=780.18 max_intensity=1265425.41,
#   KnownChemical - 'C4H8S4' rt=459.85 max_intensity=3572824.29,
#   KnownChemical - 'C10H12' rt=409.41 max_intensity=20678407.98,
#   KnownChemical - 'C5H12O2S5' rt=573.63 max_intensity=577470.88,
#   KnownChemical - 'C20H40O' rt=546.53 max_intensity=723746.22,
#   KnownChemical - 'H2O4S2' rt=412.42 max_intensity=295621.22,
#   KnownChemical - 'C12H13N5' rt=402.45 max_intensity=679401.52,
#   KnownChemical - 'C8H7NS' rt=429.61 max_intensity=205408.84,
#   KnownChemical - 'C8H17NOSi' rt=608.03 max_intensity=4510015.60,
#   KnownChemical - 'C5H9NO2' rt=602.67 max_intensity=16337213.12,
#   KnownChemical - 'C9H10O4S' rt=584.42 max_intensity=9217764.86,
#   KnownChemical - 'C15H26O' rt=716.18 max_intensity=328980.06,
#   KnownChemical - 'C16H38N2' rt=638.33 max_intensity=462745.12,
#   KnownChemical - 'C8H10' rt=537.45 max_intensity=12959237.69,
#   KnownChemical - 'C8H13N3O6' rt=671.75 max_intensity=1328113.77,
#   KnownChemical - 'C5H6OS2' rt=465.43 max_intensity=340276.02,
#   KnownChemical - 'C10H17NO3' rt=564.16 max_intensity=1196245.42,
#   KnownChemical - 'C7H10O' rt=617.75 max_intensity=1098489.27,
#   KnownChemical - 'C10H19NOS2' rt=513.35 max_intensity=24595788.64,
#   KnownChemical - 'C2H3Cl3O' rt=396.76 max_intensity=524066.20,
#   KnownChemical - 'C9H11NO2' rt=476.24 max_intensity=2454227.41,
#   KnownChemical - 'C13H25NO' rt=696.80 max_intensity=961852.72,
#   KnownChemical - 'C5H5N5O' rt=791.52 max_intensity=248754.75,
#   KnownChemical - 'C16H12O7' rt=695.12 max_intensity=951744.80,
#   KnownChemical - 'C13H28' rt=674.69 max_intensity=3506883.32,
#   KnownChemical - 'C10H7Cl2N3O' rt=408.64 max_intensity=306582.69,
#   KnownChemical - 'C6H11O8P' rt=450.30 max_intensity=176675.65,
#   KnownChemical - 'C21H36NO' rt=445.30 max_intensity=203689.54,
#   KnownChemical - 'C10H11NO6' rt=406.48 max_intensity=3657675.86,
#   KnownChemical - 'C2HF3O2' rt=658.87 max_intensity=1422126.67,
#   KnownChemical - 'C14H16O8' rt=519.10 max_intensity=413770.14,
#   KnownChemical - 'C6H6O8S2' rt=503.16 max_intensity=26513397.15,
#   KnownChemical - 'C10H12N4O6' rt=546.07 max_intensity=440712.97,
#   KnownChemical - 'C14H12ClNO2' rt=611.89 max_intensity=623825.45,
#   KnownChemical - 'C9H8O8S' rt=719.25 max_intensity=26555066.73,
#   KnownChemical - 'C18H30O' rt=775.69 max_intensity=1526626.98,
#   KnownChemical - 'C12H12N2O2S2' rt=552.29 max_intensity=445540391.30,
#   KnownChemical - 'C11H24' rt=685.45 max_intensity=394849.91,
#   KnownChemical - 'C16H15Cl2N' rt=427.42 max_intensity=318449.09,
#   KnownChemical - 'C10H15N' rt=423.59 max_intensity=455769.41,
#   KnownChemical - 'C13H20' rt=621.06 max_intensity=1568705.44,
#   KnownChemical - 'C3H12NO9P3' rt=771.80 max_intensity=822467.32,
#   KnownChemical - 'C11H15N2O' rt=425.38 max_intensity=19460989.91,
#   KnownChemical - 'C6H13N3O4' rt=738.28 max_intensity=230298.28,
#   KnownChemical - 'C7H9NO4S' rt=410.94 max_intensity=10819698.20,
#   KnownChemical - 'C8H21N3' rt=588.39 max_intensity=35509172.90,
#   KnownChemical - 'C11H17NO' rt=414.66 max_intensity=373393.38,
#   KnownChemical - 'C4H6O2S' rt=573.52 max_intensity=258412.00,
#   KnownChemical - 'C9H14N2' rt=579.14 max_intensity=269873.99,
#   KnownChemical - 'C14H19NO' rt=425.11 max_intensity=528985.74,
#   KnownChemical - 'C3H6S3' rt=397.17 max_intensity=369193.15,
#   KnownChemical - 'C8H7NO4' rt=550.78 max_intensity=309590.79,
#   KnownChemical - 'C17H20N2O2' rt=600.64 max_intensity=581291.86,
#   KnownChemical - 'C7H9NOS' rt=657.48 max_intensity=1127593.34,
#   KnownChemical - 'C18H25NO8' rt=784.21 max_intensity=515406.95,
#   KnownChemical - 'C17H25NO2' rt=434.66 max_intensity=1475119.14,
#   KnownChemical - 'C7H16O13P2' rt=694.80 max_intensity=461988.87,
#   KnownChemical - 'C8H11NO6S' rt=730.86 max_intensity=409248.74,
#   KnownChemical - 'C22H37NO3' rt=781.57 max_intensity=6710617.99,
#   KnownChemical - 'C13H18N2O' rt=557.91 max_intensity=175858.21,
#   KnownChemical - 'C14H11ClN2O4S' rt=408.76 max_intensity=1443037.98,
#   KnownChemical - 'C14H26O2' rt=536.30 max_intensity=518450.10,
#   KnownChemical - 'C11H20' rt=481.62 max_intensity=3723916.73,
#   KnownChemical - 'C9H18O' rt=713.33 max_intensity=11120273.36,
#   KnownChemical - 'C7H8O4' rt=397.54 max_intensity=329645.20,
#   KnownChemical - 'C11H13NO2' rt=544.42 max_intensity=340614.69,
#   KnownChemical - 'C9H17O12P' rt=418.14 max_intensity=423028.83,
#   KnownChemical - 'C18H37NO' rt=736.58 max_intensity=1725907.19,
#   KnownChemical - 'C10H10O8S' rt=760.98 max_intensity=1669143.17,
#   KnownChemical - 'C15H32O' rt=547.71 max_intensity=280280.08,
#   KnownChemical - 'C21H41NO4' rt=552.27 max_intensity=619447.64,
#   KnownChemical - 'CCl3NO2' rt=620.39 max_intensity=221034.05,
#   KnownChemical - 'C4H13N3' rt=424.64 max_intensity=492224.66,
#   KnownChemical - 'C16H13ClN2O3' rt=728.55 max_intensity=5685655.27,
#   KnownChemical - 'C5H6O5' rt=786.85 max_intensity=731948.15,
#   KnownChemical - 'C8H18N4O2' rt=782.99 max_intensity=1044876.13,
#   KnownChemical - 'C8H23N5' rt=571.79 max_intensity=12501656.14]]

# %% [markdown]
# ## Run MS1 controller on the samples and generate .mzML files

# %% [markdown]
# We can now take the multiple samples created above and generate mass spectral data (.mzML files) using the MS1 controller in ViMMS.

# %%
min_rt = rt_range[0][0]
max_rt = rt_range[0][1]
controllers = defaultdict(list)
controller_to_mzml = {}

mzml_dir = Path(out_dir, 'mzMLFiles')
num_classes = len(n_samples)
sample_idx = 0
for j in range(num_classes): # loop over classes
    num_samples = n_samples[j]
    for i in range(num_samples): # loop over samples for each class
        
        # load the sample
        fname = Path(save_location, 'sample_%d.p' % sample_idx) 
        sample = load_obj(fname)
        sample_idx += 1
        
        # define output .mzML filename
        out_file = 'number_%d_class_%d.mzML' % (i, j)
        out_path = Path(mzml_dir, out_file)

        # run it through the MS1 controller        
        mass_spec = IndependentMassSpectrometer(POSITIVE, sample, ps)
        controller = SimpleMs1Controller()
        
        # create an environment to run both the mass spec and controller
        env = Environment(mass_spec, controller, min_rt, max_rt, progress_bar=True)

        # set the log level to WARNING so we don't see too many messages when environment is running
        set_log_level_warning()

        # run the simulation
        env.run()

        set_log_level_debug()
        env.write_mzML(mzml_dir, out_file)        
        
        # save the resulting controller
        controllers[j].append(controller)
        controller_to_mzml[controller] = (j, out_file, )
# Out:
# (800.492s) ms_level=1: 100%|█████████▉| 399.25193999999993/400 [00:04<00:00, 86.83it/s]
# 2019-12-12 11:41:42.274 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_0_class_0.mzML
# 2019-12-12 11:41:43.870 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.622s) ms_level=1: 100%|█████████▉| 399.3478500000002/400 [00:04<00:00, 83.88it/s]
# 2019-12-12 11:41:48.652 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_1_class_0.mzML
# 2019-12-12 11:41:49.237 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (801.108s) ms_level=1: 100%|█████████▉| 399.8484800000002/400 [00:04<00:00, 84.49it/s]
# 2019-12-12 11:41:53.992 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_2_class_0.mzML
# 2019-12-12 11:41:54.611 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.834s) ms_level=1: 100%|█████████▉| 399.59027999999995/400 [00:04<00:00, 84.51it/s]
# 2019-12-12 11:41:59.369 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_3_class_0.mzML
# 2019-12-12 11:41:59.995 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.141s) ms_level=1: 100%|█████████▉| 398.85725000000184/400 [00:05<00:00, 77.88it/s]
# 2019-12-12 11:42:05.150 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_4_class_0.mzML
# 2019-12-12 11:42:05.748 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.920s) ms_level=1: 100%|█████████▉| 399.43962999999917/400 [00:04<00:00, 80.75it/s]
# 2019-12-12 11:42:10.720 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_5_class_0.mzML
# 2019-12-12 11:42:11.306 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.088s) ms_level=1: 100%|█████████▉| 398.7942999999983/400 [00:04<00:00, 81.16it/s]
# 2019-12-12 11:42:16.246 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_6_class_0.mzML
# 2019-12-12 11:42:16.860 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.810s) ms_level=1: 100%|█████████▉| 399.5733400000001/400 [00:04<00:00, 85.01it/s]
# 2019-12-12 11:42:21.584 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_7_class_0.mzML
# 2019-12-12 11:42:22.203 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.097s) ms_level=1: 100%|█████████▉| 398.83757000000236/400 [00:04<00:00, 88.25it/s]
# 2019-12-12 11:42:26.747 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_8_class_0.mzML
# 2019-12-12 11:42:27.352 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.615s) ms_level=1: 100%|█████████▉| 399.3532999999985/400 [00:04<00:00, 88.33it/s]
# 2019-12-12 11:42:31.897 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_9_class_0.mzML
# 2019-12-12 11:42:32.507 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.625s) ms_level=1: 100%|█████████▉| 398.98659999999785/400 [00:04<00:00, 84.50it/s]
# 2019-12-12 11:42:37.252 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_0_class_1.mzML
# 2019-12-12 11:42:37.863 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.509s) ms_level=1: 100%|█████████▉| 399.2481499999998/400 [00:04<00:00, 80.06it/s]
# 2019-12-12 11:42:42.874 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_1_class_1.mzML
# 2019-12-12 11:42:43.510 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.335s) ms_level=1: 100%|█████████▉| 399.09409999999895/400 [00:04<00:00, 81.12it/s]
# 2019-12-12 11:42:48.456 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_2_class_1.mzML
# 2019-12-12 11:42:49.078 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.823s) ms_level=1: 100%|█████████▉| 399.3126000000006/400 [00:05<00:00, 77.12it/s]
# 2019-12-12 11:42:54.280 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_3_class_1.mzML
# 2019-12-12 11:42:54.914 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (801.072s) ms_level=1: 100%|█████████▉| 399.81030999999933/400 [00:05<00:00, 79.20it/s]
# 2019-12-12 11:42:59.988 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_4_class_1.mzML
# 2019-12-12 11:43:00.646 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.404s) ms_level=1: 100%|█████████▉| 399.1626000000015/400 [00:04<00:00, 82.72it/s]
# 2019-12-12 11:43:05.498 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_5_class_1.mzML
# 2019-12-12 11:43:06.123 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (801.170s) ms_level=1: 100%|█████████▉| 399.9305800000003/400 [00:04<00:00, 84.26it/s]
# 2019-12-12 11:43:10.893 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_6_class_1.mzML
# 2019-12-12 11:43:11.602 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (801.321s) ms_level=1: 100%|█████████▉| 399.86965999999956/400 [00:05<00:00, 77.74it/s]
# 2019-12-12 11:43:16.770 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_7_class_1.mzML
# 2019-12-12 11:43:17.383 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (800.165s) ms_level=1: 100%|█████████▉| 398.92992199999975/400 [00:04<00:00, 85.99it/s]
# 2019-12-12 11:43:22.047 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_8_class_1.mzML
# 2019-12-12 11:43:22.705 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!
# (801.068s) ms_level=1: 100%|█████████▉| 399.8248300000001/400 [00:04<00:00, 86.14it/s]
# 2019-12-12 11:43:27.371 | DEBUG    | vimms.Environment:write_mzML:142 - Writing mzML file to /home/joewandy/git/vimms/examples/example_data/results/MS1_multiple/mzMLFiles/number_9_class_1.mzML
# 2019-12-12 11:43:27.980 | DEBUG    | vimms.Environment:write_mzML:149 - mzML file successfully written!

# %% [markdown]
# ## Print out the missing peaks

# %% [markdown]
# The controller object contains all the information about the state of the mass spectrometry process over time. Below we demonstrate this by generating a report of peaks corresponding to a chemical that are present in one class but is missing from the other class. This can be useful in the benchmark evaluation of peak picking or alignment algorithms.

# %%
def get_chem_to_peaks(controller):
    chem_to_peaks = defaultdict(list)
    frag_events = controller.environment.mass_spec.fragmentation_events
    for frag_event in frag_events:
        chem = frag_event.chem
        peaks = frag_event.peaks
        chem_to_peaks[chem].extend(peaks)
    return chem_to_peaks

# %%
for controller, (current_class, mzml_filename) in controller_to_mzml.items():
    controller_peaks = get_chem_to_peaks(controller)
    basename = os.path.basename(mzml_filename)
    front, back = os.path.splitext(mzml_filename)
    outfile = front + '.csv'

    missing_peaks = []            
    for other_class in range(num_classes):
        if current_class == other_class:
            continue

        # get the peaks that are present in current_class but missing in other_class
        missing_chems = multiple_samples.missing_chemicals[other_class]
        for chem in missing_chems:
            peaks = controller_peaks[chem]
            for peak in peaks:
                row = (chem.formula.formula_string, current_class, other_class, peak.mz, peak.rt, peak.intensity)
                missing_peaks.append(row)
    
    # convert to dataframe
    columns = ['formula', 'present_in', 'missing_in', 'mz', 'RT', 'intensity']
    missing_df = pd.DataFrame(missing_peaks, columns=columns)
    missing_df.to_csv(os.path.join(out_dir, 'MissingChemicals', os.path.basename(outfile)))

# %%
missing_df.head(20)
# Out:
#      formula  present_in  missing_in          mz         RT      intensity
# 0   C19H35NO           1           0  294.279134  413.22900  248626.544988
# 1   C19H35NO           1           0  316.261076  413.22900   59585.785134
# 2   C19H35NO           1           0  370.190898  413.22900  235838.554105
# 3   C19H35NO           1           0  372.293078  413.22900  192729.935184
# 4   C19H35NO           1           0  295.282489  413.22900   52540.897778
# 5   C19H35NO           1           0  296.285844  413.22900    5259.402305
# 6   C19H35NO           1           0  294.279117  414.47400  338849.932780
# 7   C19H35NO           1           0  316.261059  414.47400   81208.703150
# 8   C19H35NO           1           0  370.190881  414.47400  321421.343843
# 9   C19H35NO           1           0  372.293061  414.47400  262669.159421
# 10  C19H35NO           1           0  295.282472  414.47400   71607.316432
# 11  C19H35NO           1           0  296.285827  414.47400    7167.972019
# 12  C19H35NO           1           0  294.279149  415.75187  509905.822364
# 13  C19H35NO           1           0  316.261090  415.75187  122203.921432
# 14  C19H35NO           1           0  370.190912  415.75187  483679.053182
# 15  C19H35NO           1           0  372.293092  415.75187  395267.995615
# 16  C19H35NO           1           0  295.282504  415.75187  107755.628791
# 17  C19H35NO           1           0  296.285858  415.75187   10786.458291
# 18  C19H35NO           1           0  294.279186  416.99387  388282.750095
# 19  C19H35NO           1           0  316.261127  416.99387   93055.761682
